# %%
import mysql.connector
import pandas as pd
from collections import defaultdict

def create_connection():
    try:
        connection = mysql.connector.connect(
            host='localhost',
            port=3306,
            user='root',
            password='123456',
            database='ASTOCK'
        )
        return connection
    except mysql.connector.Error as e:
        print(f"连接MySQL失败: {e}")
        return None

# %%
def get_min_market_value(year, month) -> list:
    # 获取市值数据
    market_values = get_market_values(year, month)

    # 按市值排序，选择前N个标的
    top_n = 10
    sorted_symbols = sorted(market_values, key=lambda x: x["market_value"])[:top_n]
    return sorted_symbols

def get_market_values(year, month) -> list:
    connection = create_connection()
    if not connection:
        return []
    
    finance_report_months = ['12', '03', '06', '09']
    year_of_interest = year - 1 if month < 4 else year
    report_month_of_interest = str(year_of_interest) + "-" + finance_report_months[(month - 1) // 3]

    cursor = connection.cursor()
    sql = f'''SELECT 
            a.symbol, a.name, a.update_time, (a.total_shares * b.close_price) AS market_value
            FROM finance a
            JOIN (
                SELECT 
                    symbol,
                    datetime,
                    close_price,
                    ROW_NUMBER() OVER (
                        PARTITION BY symbol, YEAR(datetime), MONTH(datetime) 
                        ORDER BY datetime DESC
                    ) as rn
                FROM daily
                WHERE exchange = 'SZSE'
                    AND datetime like '{report_month_of_interest}-%'
            ) b 
            ON a.symbol = b.symbol 
                AND YEAR(a.update_time) = YEAR(b.datetime)
                AND MONTH(a.update_time) = MONTH(b.datetime)
                AND b.rn = 1
            WHERE a.market = '深市'
                AND a.update_time like '{report_month_of_interest}-%'
                AND a.symbol like '00%'
                AND a.name not like '%ST%'
                AND a.name not like '%退'
            ;'''
    # print(f"SQL查询语句: {sql}")
    cursor.execute(sql)
    rows = cursor.fetchall()
    cursor.close()
    connection.close()

    # 将查询结果转换为字典列表
    values = [{"symbol": row[0], "name": row[1], "market_value": row[3]} for row in rows]
    return values

def convert_list_to_df(list_data)->pd.DataFrame:
    df = pd.DataFrame()
    results = defaultdict(list)
    for data in list_data:
        for key, value in data.__dict__.items():
            results[key].append(value)
    if len(results) > 0:
        df = pd.DataFrame.from_dict(results).set_index('datetime')
    return df

# %%
from vnpy.trader.optimize import OptimizationSetting
from vnpy_ctastrategy.backtesting import BacktestingEngine
from datetime import datetime
import sys
import os
import copy

parent_dir = os.path.abspath(os.path.join(os.path.curdir, ".."))
sys.path.append(parent_dir)
from chart_tools import data
from strategies.monthly_min_market_value_strategy import MonthlyMinMarketValueStrategy
from tools.common import sum_specified_keep_others

goods_symbols = []

start_day = datetime(2024, 4, 1)
end_day = datetime(2025, 3, 31)
data.set_start_date(start_day)
data.set_end_date(end_day)

month_first_list = []
# current_date = start_day.replace(day=1)  # 确保从每月的1日开始
current_date = start_day

while current_date <= end_day:
    month_first_list.append(current_date)

    if current_date.month == 12:
        current_date = current_date.replace(year=current_date.year + 1, month=1, day=1)
    else:
        current_date = current_date.replace(month=current_date.month + 1, day=1)

print(month_first_list)

capital = 1000000
total_profits = list()

record_df_dicts = list()
record_candle_dicts = list()
record_engines = list()
integrated_df = pd.DataFrame()
dfs = list()
for i in range(len(month_first_list)):
    if i > 0:
        capital += total_profits[i - 1] / 10  # add profit
    record_df_dicts.append({})
    record_candle_dicts.append({})
    start = month_first_list[i]
    end = month_first_list[i + 1] if i + 1 < len(month_first_list) else end_day
    end = end.replace(month=end.month + 1, day=9) if end.month < 12 else end.replace(year=end.year+1 ,month=1, day=9) # for sell
    print(f"开始日期: {start}")
    
    min_market_symbols = get_min_market_value(start.year, start.month)

    # sort by market value
    symbols_candidates = min_market_symbols[:]
    month_profits = list() 
    month_profit = 0
    print(f"候选标的：{symbols_candidates}")

    for symbol in symbols_candidates:
        engine = BacktestingEngine()
        vt_symbol = symbol["symbol"] + ".SZSE"
        engine.set_parameters(
            vt_symbol=vt_symbol,
            interval="d",
            start=start,
            end=end,
            rate=0.3/10000,
            slippage=0.2,
            size=100,
            pricetick=0.2,
            capital=capital,
        )
        engine.add_strategy(MonthlyMinMarketValueStrategy, {"initial_capital": capital, "current_month": start.month})

        engine.load_data()
        engine.run_backtesting()
        df = engine.calculate_result()
        dfs.append(df)
        
        record_df_dicts[i][symbol["symbol"]] = df
        record_candle_dicts[i][symbol["symbol"]] = engine.history_data
        res = engine.calculate_statistics(output=False)
        engine.cross_stop_order
        print(f"策略回测成功：{symbol['symbol']}，总净利润：{res['total_net_pnl']}")
        month_profits.append(res["total_net_pnl"])
        record_engines.append(copy.deepcopy(engine))
        
        data.add_tech_data(vt_symbol, 'daily_df', df)
        data.add_trade_data(vt_symbol, convert_list_to_df(engine.get_all_trades()))
        if res["total_net_pnl"] > 0:
            goods_symbols.append({"symbol": symbol["symbol"], "total_net_pnl": res["total_net_pnl"]})
    month_profit = sum(month_profits)
    print(f"{start.year}-{start.month}月总净利润：{month_profit}")
    total_profits.append(month_profit)

integrated_df = sum_specified_keep_others(dfs, sum_columns=['trade_count', 'turnover', 'commission', 'slippage', 'trading_pnl', 'holding_pnl', 'total_pnl', 'net_pnl'])
engine = BacktestingEngine()
intergrated_result = engine.calculate_statistics(integrated_df, output=False, capital=10000000)
print(f"总净利润：{sum(total_profits)}")
# Out:
# [datetime.datetime(2024, 4, 1, 0, 0), datetime.datetime(2024, 5, 1, 0, 0), datetime.datetime(2024, 6, 1, 0, 0), datetime.datetime(2024, 7, 1, 0, 0), datetime.datetime(2024, 8, 1, 0, 0), datetime.datetime(2024, 9, 1, 0, 0), datetime.datetime(2024, 10, 1, 0, 0), datetime.datetime(2024, 11, 1, 0, 0), datetime.datetime(2024, 12, 1, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 2, 1, 0, 0), datetime.datetime(2025, 3, 1, 0, 0)]
# 开始日期: 2024-04-01 00:00:00
# 候选标的：[{'symbol': '002856', 'name': '美芝股份', 'market_value': 1165043208.0}, {'symbol': '002633', 'name': '申科股份', 'market_value': 1219500000.0}, {'symbol': '002193', 'name': '如意集团', 'market_value': 1219594472.32}, {'symbol': '002629', 'name': '仁智股份', 'market_value': 1231347360.0}, {'symbol': '001211', 'name': '双枪科技', 'market_value': 1250640000.0}, {'symbol': '002652', 'name': '扬子新材', 'market_value': 1341607680.0}, {'symbol': '000692', 'name': '惠天热电', 'market_value': 1406679014.4}, {'symbol': '000953', 'name': '河化股份', 'market_value': 1424215389.1200001}, {'symbol': '002247', 'name': '聚力文化', 'market_value': 1429461734.3999999}, {'symbol': '002207', 'name': '准油股份', 'market_value': 1454407336.8}]
# 正在使用mysql数据库
# 2025-07-31 10:34:01.988957	历史数据加载完成，数据量：45
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002856, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 919.0, 目标价格: 10.87
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 11.8, 数量: 919.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002856, 日期: 2024-04-16 00:00:00+08:00, 交易单位: 919.0, 目标仓位: 0, 目标价格: 7.88
# 订单状态更新: Status.ALLTRADED, 价格: 6.8, 数量: 919.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002856, 日期: 2024-04-18 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.25
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002856, 日期: 2024-04-19 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002856, 日期: 2024-04-22 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.6
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002856, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.39
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002856, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.93
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# 2025-07-31 10:34:02.003171	逐日盯市盈亏计算完成
# 2025-07-31 10:34:02.003233	开始计算策略统计指标
# 2025-07-31 10:34:02.019311	策略统计指标计算完成
# 策略回测成功：002856，总净利润：-368568.76385000005
# 2025-07-31 10:34:02.033832	历史数据加载完成，数据量：45
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002633, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 784.0, 目标价格: 12.74
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 13.8, 数量: 784.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002633, 日期: 2024-04-17 00:00:00+08:00, 交易单位: 784.0, 目标仓位: 0, 目标价格: 9.61
# 订单状态更新: Status.ALLTRADED, 价格: 8.6, 数量: 784.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002633, 日期: 2024-04-18 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.73
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002633, 日期: 2024-04-19 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.61
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002633, 日期: 2024-04-22 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002633, 日期: 2024-04-26 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.13
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002633, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.02
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002633, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.91
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002633, 日期: 2024-06-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.56
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# 2025-07-31 10:34:02.036634	逐日盯市盈亏计算完成
# 2025-07-31 10:34:02.036656	开始计算策略统计指标
# 2025-07-31 10:34:02.039338	策略统计指标计算完成
# 策略回测成功：002633，总净利润：-279940.84944
# 2025-07-31 10:34:02.049430	历史数据加载完成，数据量：45
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002193, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 948.0, 目标价格: 10.54
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 11.6, 数量: 948.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002193, 日期: 2024-04-16 00:00:00+08:00, 交易单位: 948.0, 目标仓位: 0, 目标价格: 7.96
# 订单状态更新: Status.ALLTRADED, 价格: 7.0, 数量: 948.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002193, 日期: 2024-04-18 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002193, 日期: 2024-04-19 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.64
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002193, 日期: 2024-04-22 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.26
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002193, 日期: 2024-04-23 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.54
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002193, 日期: 2024-04-24 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.7
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002193, 日期: 2024-04-26 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.74
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002193, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.98
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002193, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.86
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002193, 日期: 2024-06-04 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.46
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002193, 日期: 2024-06-05 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.16
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002193, 日期: 2024-06-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.62
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# 2025-07-31 10:34:02.052673	逐日盯市盈亏计算完成
# 2025-07-31 10:34:02.052697	开始计算策略统计指标
# 2025-07-31 10:34:02.055181	策略统计指标计算完成
# 策略回测成功：002193，总净利润：-293932.0452
# 2025-07-31 10:34:02.067025	历史数据加载完成，数据量：45
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002629, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 892.0, 目标价格: 11.2
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 12.2, 数量: 892.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002629, 日期: 2024-04-16 00:00:00+08:00, 交易单位: 892.0, 目标仓位: 0, 目标价格: 8.79
# 订单状态更新: Status.ALLTRADED, 价格: 7.8, 数量: 892.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002629, 日期: 2024-04-17 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.93
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002629, 日期: 2024-04-18 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.04
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002629, 日期: 2024-04-22 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.57
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002629, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.58
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002629, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.21
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002629, 日期: 2024-06-04 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.92
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002629, 日期: 2024-06-05 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.31
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002629, 日期: 2024-06-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.84
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002629, 日期: 2024-06-07 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.2
# 2025-07-31 10:34:02.069995	逐日盯市盈亏计算完成
# 2025-07-31 10:34:02.070016	开始计算策略统计指标
# 2025-07-31 10:34:02.072184	策略统计指标计算完成
# 策略回测成功：002629，总净利润：-306007.8341199999
# 2025-07-31 10:34:02.082681	历史数据加载完成，数据量：45
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 001211, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 526.0, 目标价格: 19.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 20.0, 数量: 526.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 001211, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 526.0, 目标仓位: 0, 目标价格: 18.91
# 订单状态更新: Status.ALLTRADED, 价格: 18.0, 数量: 526.0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 001211, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 17.19
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 001211, 日期: 2024-06-04 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 16.86
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 001211, 日期: 2024-06-05 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 16.56
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 001211, 日期: 2024-06-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 15.69
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# 2025-07-31 10:34:02.085282	逐日盯市盈亏计算完成
# 2025-07-31 10:34:02.085300	开始计算策略统计指标
# 2025-07-31 10:34:02.087299	策略统计指标计算完成
# 策略回测成功：001211，总净利润：-25833.821979999993
# 2025-07-31 10:34:02.097905	历史数据加载完成，数据量：45
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002652, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 715.0, 目标价格: 13.98
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 15.0, 数量: 715.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002652, 日期: 2024-04-16 00:00:00+08:00, 交易单位: 715.0, 目标仓位: 0, 目标价格: 10.81
# 订单状态更新: Status.ALLTRADED, 价格: 9.8, 数量: 715.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002652, 日期: 2024-04-18 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002652, 日期: 2024-04-19 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.01
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002652, 日期: 2024-04-22 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.77
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002652, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 12.88
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002652, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.68
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002652, 日期: 2024-06-04 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.2
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002652, 日期: 2024-06-05 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.05
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# 2025-07-31 10:34:02.100527	逐日盯市盈亏计算完成
# 2025-07-31 10:34:02.100550	开始计算策略统计指标
# 2025-07-31 10:34:02.102471	策略统计指标计算完成
# 策略回测成功：002652，总净利润：-241008.38904999994
# 2025-07-31 10:34:02.114049	历史数据加载完成，数据量：44
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 000692, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 789.0, 目标价格: 12.66
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 13.6, 数量: 789.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000692, 日期: 2024-04-10 00:00:00+08:00, 交易单位: 789.0, 目标仓位: 0, 目标价格: 11.47
# 订单状态更新: Status.ALLTRADED, 价格: 10.4, 数量: 789.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000692, 日期: 2024-04-12 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.16
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000692, 日期: 2024-04-17 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.22
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000692, 日期: 2024-04-18 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.58
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000692, 日期: 2024-04-19 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 5.39
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000692, 日期: 2024-04-22 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.46
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000692, 日期: 2024-04-23 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.65
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 000692, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 14.21
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 000692, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 18.02
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# 2025-07-31 10:34:02.116535	逐日盯市盈亏计算完成
# 2025-07-31 10:34:02.116557	开始计算策略统计指标
# 2025-07-31 10:34:02.118403	策略统计指标计算完成
# 策略回测成功：000692，总净利润：-87634.41147000004
# 2025-07-31 10:34:02.129023	历史数据加载完成，数据量：45
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 000953, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 1184.0, 目标价格: 8.44
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 9.4, 数量: 1184.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000953, 日期: 2024-04-16 00:00:00+08:00, 交易单位: 1184.0, 目标仓位: 0, 目标价格: 6.6
# 订单状态更新: Status.ALLTRADED, 价格: 5.6, 数量: 1184.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000953, 日期: 2024-04-17 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.52
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000953, 日期: 2024-04-18 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.46
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000953, 日期: 2024-04-19 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.4
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000953, 日期: 2024-04-22 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000953, 日期: 2024-04-23 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.38
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 000953, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.25
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 000953, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.18
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000953, 日期: 2024-06-04 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 5.8
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000953, 日期: 2024-06-05 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 5.63
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 000953, 日期: 2024-06-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 5.11
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# 2025-07-31 10:34:02.131554	逐日盯市盈亏计算完成
# 2025-07-31 10:34:02.131575	开始计算策略统计指标
# 2025-07-31 10:34:02.133283	策略统计指标计算完成
# 策略回测成功：000953，总净利润：-336307.29088
# 2025-07-31 10:34:02.143402	历史数据加载完成，数据量：45
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002247, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 730.0, 目标价格: 13.68
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 14.6, 数量: 730.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002247, 日期: 2024-04-16 00:00:00+08:00, 交易单位: 730.0, 目标仓位: 0, 目标价格: 10.74
# 订单状态更新: Status.ALLTRADED, 价格: 9.8, 数量: 730.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002247, 日期: 2024-04-18 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.04
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002247, 日期: 2024-04-19 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.92
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002247, 日期: 2024-04-22 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.92
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002247, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.76
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002247, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.22
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# 2025-07-31 10:34:02.145789	逐日盯市盈亏计算完成
# 2025-07-31 10:34:02.145809	开始计算策略统计指标
# 2025-07-31 10:34:02.147487	策略统计指标计算完成
# 策略回测成功：002247，总净利润：-274532.2972
# 2025-07-31 10:34:02.158033	历史数据加载完成，数据量：45
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002207, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 865.0, 目标价格: 11.56
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 12.6, 数量: 865.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002207, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 865.0, 目标仓位: 0, 目标价格: 11.48
# 订单状态更新: Status.ALLTRADED, 价格: 10.4, 数量: 865.0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002207, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.34
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002207, 日期: 2024-06-04 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.92
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002207, 日期: 2024-06-05 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.92
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002207, 日期: 2024-06-06 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.48
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002207, 日期: 2024-06-07 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.78
# 2025-07-31 10:34:02.160614	逐日盯市盈亏计算完成
# 2025-07-31 10:34:02.160636	开始计算策略统计指标
# 2025-07-31 10:34:02.162301	策略统计指标计算完成
# 策略回测成功：002207，总净利润：-38119.99640000006
# 2024-4月总净利润：-2251885.69959
# 开始日期: 2024-05-01 00:00:00
# 候选标的：[{'symbol': '002856', 'name': '美芝股份', 'market_value': 1165043208.0}, {'symbol': '002633', 'name': '申科股份', 'market_value': 1219500000.0}, {'symbol': '002193', 'name': '如意集团', 'market_value': 1219594472.32}, {'symbol': '002629', 'name': '仁智股份', 'market_value': 1231347360.0}, {'symbol': '001211', 'name': '双枪科技', 'market_value': 1250640000.0}, {'symbol': '002652', 'name': '扬子新材', 'market_value': 1341607680.0}, {'symbol': '000692', 'name': '惠天热电', 'market_value': 1406679014.4}, {'symbol': '000953', 'name': '河化股份', 'market_value': 1424215389.1200001}, {'symbol': '002247', 'name': '聚力文化', 'market_value': 1429461734.3999999}, {'symbol': '002207', 'name': '准油股份', 'market_value': 1454407336.8}]
# 2025-07-31 10:34:07.584923	历史数据加载完成，数据量：46
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002856, 日期: 2024-05-06 00:00:00+08:00, 当前资金: 774811.430041, 交易单位: 100, 目标仓位: 825.0, 目标价格: 9.39
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 10.4, 数量: 825.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002856, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 825.0, 目标仓位: 0, 目标价格: 9.93
# 订单状态更新: Status.ALLTRADED, 价格: 9.0, 数量: 825.0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002856, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.35
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ...
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 001211, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1136803.895429, 交易单位: 100, 目标仓位: 495.0, 目标价格: 22.92
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 24.0, 数量: 495.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 001211, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 495.0, 目标仓位: 0, 目标价格: 22.67
# 订单状态更新: Status.ALLTRADED, 价格: 21.6, 数量: 495.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 001211, 日期: 2025-04-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 20.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# 2025-07-31 10:35:08.526801	逐日盯市盈亏计算完成
# 2025-07-31 10:35:08.526854	开始计算策略统计指标
# 2025-07-31 10:35:08.528440	策略统计指标计算完成
# 策略回测成功：001211，总净利润：-12938.30999999998
# 2025-07-31 10:35:08.544530	历史数据加载完成，数据量：27
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 001336, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1136803.895429, 交易单位: 100, 目标仓位: 591.0, 目标价格: 19.21
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 20.2, 数量: 591.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 001336, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 591.0, 目标仓位: 0, 目标价格: 24.21
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# 2025-07-31 10:35:08.548655	逐日盯市盈亏计算完成
# 2025-07-31 10:35:08.548710	开始计算策略统计指标
# 2025-07-31 10:35:08.550361	策略统计指标计算完成
# 策略回测成功：001336，总净利润：-114687.91748999985
# 2025-07-31 10:35:08.567875	历史数据加载完成，数据量：27
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002921, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1136803.895429, 交易单位: 100, 目标仓位: 608.0, 目标价格: 18.68
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 19.6, 数量: 608.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002921, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 608.0, 目标仓位: 0, 目标价格: 19.85
# 订单状态更新: Status.ALLTRADED, 价格: 18.8, 数量: 608.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002921, 日期: 2025-04-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 16.53
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002921, 日期: 2025-04-09 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 16.96
# 2025-07-31 10:35:08.571937	逐日盯市盈亏计算完成
# 2025-07-31 10:35:08.571995	开始计算策略统计指标
# 2025-07-31 10:35:08.574015	策略统计指标计算完成
# 策略回测成功：002921，总净利润：33977.4476800001
# 2025-07-31 10:35:08.635572	历史数据加载完成，数据量：27
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002652, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1136803.895429, 交易单位: 100, 目标仓位: 743.0, 目标价格: 15.28
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 16.2, 数量: 743.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002652, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 743.0, 目标仓位: 0, 目标价格: 13.98
# 订单状态更新: Status.ALLTRADED, 价格: 13.0, 数量: 743.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002652, 日期: 2025-04-07 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 12.88
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002652, 日期: 2025-04-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 12.35
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002652, 日期: 2025-04-09 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 12.69
# 2025-07-31 10:35:08.640042	逐日盯市盈亏计算完成
# 2025-07-31 10:35:08.640106	开始计算策略统计指标
# 2025-07-31 10:35:08.642016	策略统计指标计算完成
# 策略回测成功：002652，总净利润：-107800.33198999992
# 2025-07-31 10:35:08.660865	历史数据加载完成，数据量：27
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002910, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1136803.895429, 交易单位: 100, 目标仓位: 1034.0, 目标价格: 10.99
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 12.0, 数量: 1034.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 1, ma_cross_10: 1, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002910, 日期: 2025-03-25 00:00:00+08:00, 交易单位: 1034.0, 目标仓位: 0, 目标价格: 9.18
# 订单状态更新: Status.ALLTRADED, 价格: 8.2, 数量: 1034.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002910, 日期: 2025-03-26 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.24
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002910, 日期: 2025-03-27 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.18
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002910, 日期: 2025-03-28 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.99
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002910, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.97
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002910, 日期: 2025-04-07 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.15
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# 2025-07-31 10:35:08.665280	逐日盯市盈亏计算完成
# 2025-07-31 10:35:08.665341	开始计算策略统计指标
# 2025-07-31 10:35:08.667312	策略统计指标计算完成
# 策略回测成功：002910，总净利润：-126207.00004000001
# 2025-07-31 10:35:08.683075	历史数据加载完成，数据量：27
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# symbol: 002188, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1136803.895429, 交易单位: 100, 目标仓位: 1210.0, 目标价格: 9.39
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# 订单状态更新: Status.ALLTRADED, 价格: 10.4, 数量: 1210.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 1
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# symbol: 002188, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 1210.0, 目标仓位: 0, 目标价格: 8.96
# 订单状态更新: Status.ALLTRADED, 价格: 8.0, 数量: 1210.0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: 0
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002188, 日期: 2025-04-07 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.12
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002188, 日期: 2025-04-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.97
# ma_cross_signal_pos: 0, ma_cross_10: 0, ma_cross_20: 0, rsi_signal_pos: -1
# symbol: 002188, 日期: 2025-04-09 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.22
# 2025-07-31 10:35:08.689729	逐日盯市盈亏计算完成
# 2025-07-31 10:35:08.689850	开始计算策略统计指标
# 2025-07-31 10:35:08.692547	策略统计指标计算完成
# 策略回测成功：002188，总净利润：-105336.46530000008
# 2025-3月总净利润：-800013.8174099997
# 2025-07-31 10:35:08.706762	开始计算策略统计指标
# 2025-07-31 10:35:08.710144	策略统计指标计算完成
# 总净利润：568025.1368799987

# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.path.curdir, ".."))
sys.path.append(parent_dir)
from chart_tools import app
import dash
from dash import html, dcc, callback, Input, Output, State, ALL, MATCH
import plotly.graph_objects as go
from akshare.akshare.stock.stock_board_concept_em import stock_board_concept_hist_em
from akshare.akshare.stock.stock_zh_a_sina import stock_zh_a_daily
from akshare.akshare.index.index_stock_zh import stock_zh_index_daily_em
from plotly.subplots import make_subplots


app.run_server(debug=True, port=8884)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8884/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# hover_data None
# hover_data None
# hover_data None
# start date: 2024-04-01 00:00:00, end date: 2025-03-31 00:00:00, symbol: 002193.SZSE
# hover_data None
# hover_data None
# hover_data None
# hover_data None

# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.path.curdir, ".."))
sys.path.append(parent_dir)
# from chart_tools import app
import dash
from dash import html, dcc, callback, Input, Output, State, ALL, MATCH
import plotly.graph_objects as go
from akshare.akshare.stock.stock_board_concept_em import stock_board_concept_hist_em
from akshare.akshare.stock.stock_zh_a_sina import stock_zh_a_daily
from akshare.akshare.index.index_stock_zh import stock_zh_index_daily_em
from plotly.subplots import make_subplots



concept_hist_em = stock_board_concept_hist_em('微盘股', period='daily', start_date='20240401', end_date='20250331', adjust='hfq')
hs300_index_daily = stock_zh_index_daily_em('sz399300', start_date='20240401', end_date='20250331')


integrated_df["balance"] = integrated_df["net_pnl"].cumsum()
fig = go.Figure()
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(
        x = integrated_df.index,
        y = integrated_df['balance'],
    ),
    secondary_y=False
)

# fig.add_trace(go.Scatter(
#     x=concept_hist_em['日期'],
#     y=concept_hist_em['收盘']
#     ),
#     secondary_y=True
# )

fig.add_trace(go.Scatter(
    x=hs300_index_daily['date'],
    y=hs300_index_daily['close']
    ),
    secondary_y=True
)

app = dash.Dash(__name__)
app.layout = html.Div([
    # html.H1("candle图", style={'textAlign': 'center'}),
    
    # 控制面板
    html.Div([
        dcc.Graph(
            id='balance-graph',
            figure=fig
        )
    ], style={'width': '200%', 'height': '100%','margin': '20px', 'display': 'inline-block'})
])
app.run_server(debug=True, port=8883)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8883/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from collections import defaultdict

df = list(record_df_dicts[0].values())[0]

results = defaultdict(list)
test = list(record_candle_dicts[0].values())[0]
for daily_bar in test:
    for key, value in daily_bar.__dict__.items():
        results[key].append(value)
    # results['date'] = daily_bar.datetime.strftime("%Y-%m-%d %H:%M:%S")
candle_df = DataFrame.from_dict(results).set_index('datetime')
# print(type(test))
show_chart(df, candle_df)

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("atr_length", 25, 27, 1)
setting.add_parameter("atr_ma_length", 10, 30, 10)

engine.run_ga_optimization(setting)

# %%
engine.run_bf_optimization(setting)

# %%
# Out:
#            date     open    close     high      low     volume        amount
# 0    2024-04-01  3551.58  3595.65  3600.92  3551.58  162776561  2.516373e+11
# 1    2024-04-02  3593.22  3580.68  3596.19  3568.75  141272972  2.202075e+11
# 2    2024-04-03  3578.68  3567.80  3582.43  3558.87  135592331  2.142229e+11
# 3    2024-04-08  3553.56  3536.41  3567.82  3535.77  155304283  2.432493e+11
# 4    2024-04-09  3533.38  3533.49  3543.71  3518.86  129670942  1.958935e+11
# ..          ...      ...      ...      ...      ...        ...           ...
# 236  2025-03-25  3937.90  3932.30  3946.36  3921.53  140475399  2.392463e+11
# 237  2025-03-26  3930.21  3919.36  3942.03  3916.86  131164187  2.209432e+11
# 238  2025-03-27  3911.38  3932.41  3952.99  3903.65  126793738  2.321736e+11
# 239  2025-03-28  3930.78  3915.17  3934.23  3907.38  126356214  2.133792e+11
# 240  2025-03-31  3905.98  3887.31  3928.45  3872.40  166798523  2.684803e+11
#
# [241 rows x 7 columns]

# %%
# Out:
#              日期       开盘       收盘       最高       最低   涨跌幅    涨跌额       成交量  \
# 0    2024-04-01  1427.83  1460.56  1460.56  1427.83  2.62  37.27  25506320
# 1    2024-04-02  1462.32  1473.96  1479.78  1461.86  0.92  13.40  27917562
# 2    2024-04-03  1472.36  1462.38  1472.70  1440.89 -0.79 -11.58  28306878
# 3    2024-04-08  1456.58  1396.10  1456.58  1395.29 -4.53 -66.28  29838998
# 4    2024-04-09  1396.25  1425.95  1425.95  1396.25  2.14  29.85  21121380
# ..          ...      ...      ...      ...      ...   ...    ...       ...
# 236  2025-03-25  2138.46  2136.30  2150.38  2101.05 -0.22  -4.65  28397854
# 237  2025-03-26  2130.01  2188.62  2199.85  2126.33  2.45  52.32  28481226
# 238  2025-03-27  2186.46  2171.59  2188.37  2137.39 -0.78 -17.03  26832296
# 239  2025-03-28  2167.81  2123.31  2171.29  2123.28 -2.22 -48.28  22532262
# 240  2025-03-31  2108.88  2097.44  2109.31  2063.44 -1.22 -25.87  23461684
#
#               成交额    振幅   换手率
# 0    1.976344e+10  2.30  3.27
# 1    2.158200e+10  1.23  3.58
# 2    2.127419e+10  2.16  3.63
# 3    2.142211e+10  4.19  3.83
# 4    1.550453e+10  2.13  2.71
# ..            ...   ...   ...
# 236  2.230271e+10  2.30  3.64
# 237  2.210952e+10  3.44  3.65
# 238  2.106199e+10  2.33  3.44
# 239  1.795066e+10  2.21  2.89
# 240  1.779735e+10  2.16  3.01
#
# [241 rows x 11 columns]
