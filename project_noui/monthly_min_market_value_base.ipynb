# %%
import mysql.connector
import pandas as pd
from collections import defaultdict

def create_connection():
    try:
        connection = mysql.connector.connect(
            host='localhost',
            port=3306,
            user='root',
            password='123456',
            database='ASTOCK'
        )
        return connection
    except mysql.connector.Error as e:
        print(f"连接MySQL失败: {e}")
        return None

# %%
def get_min_market_value(year, month) -> list:
    # 获取市值数据
    market_values = get_market_values(year, month)

    # 按市值排序，选择前N个标的
    top_n = 10
    sorted_symbols = sorted(market_values, key=lambda x: x["market_value"])[:top_n]
    return sorted_symbols

def get_market_values(year, month) -> list:
    connection = create_connection()
    if not connection:
        return []
    
    finance_report_months = ['12', '03', '06', '09']
    year_of_interest = year - 1 if month < 4 else year
    report_month_of_interest = str(year_of_interest) + "-" + finance_report_months[(month - 1) // 3]

    cursor = connection.cursor()
    sql = f'''SELECT 
            a.symbol, a.name, a.update_time, (a.total_shares * b.close_price) AS market_value
            FROM finance a
            JOIN (
                SELECT 
                    symbol,
                    datetime,
                    close_price,
                    ROW_NUMBER() OVER (
                        PARTITION BY symbol, YEAR(datetime), MONTH(datetime) 
                        ORDER BY datetime DESC
                    ) as rn
                FROM daily
                WHERE exchange = 'SZSE'
                    AND datetime like '{report_month_of_interest}-%'
            ) b 
            ON a.symbol = b.symbol 
                AND YEAR(a.update_time) = YEAR(b.datetime)
                AND MONTH(a.update_time) = MONTH(b.datetime)
                AND b.rn = 1
            WHERE a.market = '深市'
                AND a.update_time like '{report_month_of_interest}-%'
                AND a.symbol like '00%'
                AND a.name not like '%ST%'
                AND a.name not like '%退'
            ;'''
    # print(f"SQL查询语句: {sql}")
    cursor.execute(sql)
    rows = cursor.fetchall()
    cursor.close()
    connection.close()

    # 将查询结果转换为字典列表
    values = [{"symbol": row[0], "name": row[1], "market_value": row[3]} for row in rows]
    return values

def convert_list_to_df(list_data)->pd.DataFrame:
    results = defaultdict(list)
    for data in list_data:
        for key, value in data.__dict__.items():
            results[key].append(value)
    df = pd.DataFrame.from_dict(results).set_index('datetime')
    return df

# %%
from vnpy.trader.optimize import OptimizationSetting
from vnpy_ctastrategy.backtesting import BacktestingEngine
from datetime import datetime
import sys
import os
import copy

parent_dir = os.path.abspath(os.path.join(os.path.curdir, ".."))
sys.path.append(parent_dir)
from chart_tools import data
from strategies.monthly_min_market_value_strategy_base import MonthlyMinMarketValueStrategy
from tools.common import sum_specified_keep_others

goods_symbols = []

start_day = datetime(2024, 4, 1)
end_day = datetime(2025, 3, 31)
data.set_start_date(start_day)
data.set_end_date(end_day)

month_first_list = []
# current_date = start_day.replace(day=1)  # 确保从每月的1日开始
current_date = start_day

while current_date <= end_day:
    month_first_list.append(current_date)

    if current_date.month == 12:
        current_date = current_date.replace(year=current_date.year + 1, month=1, day=1)
    else:
        current_date = current_date.replace(month=current_date.month + 1, day=1)

print(month_first_list)

capital = 1000000
total_profits = list()

record_df_dicts = list()
record_candle_dicts = list()
record_engines = list()
integrated_df = pd.DataFrame()
dfs = list()
for i in range(len(month_first_list)):
    if i > 0:
        capital += total_profits[i - 1] / 10  # add profit
    record_df_dicts.append({})
    record_candle_dicts.append({})
    start = month_first_list[i]
    end = month_first_list[i + 1] if i + 1 < len(month_first_list) else end_day
    end = end.replace(month=end.month + 1, day=9) if end.month < 12 else end.replace(year=end.year+1 ,month=1, day=9) # for sell
    print(f"开始日期: {start}")
    
    min_market_symbols = get_min_market_value(start.year, start.month)

    # sort by market value
    symbols_candidates = min_market_symbols[:]
    month_profits = list() 
    month_profit = 0
    print(f"候选标的：{symbols_candidates}")

    for symbol in symbols_candidates:
        engine = BacktestingEngine()
        vt_symbol = symbol["symbol"] + ".SZSE"
        engine.set_parameters(
            vt_symbol=vt_symbol,
            interval="d",
            start=start,
            end=end,
            rate=0.3/10000,
            slippage=0.2,
            size=100,
            pricetick=0.2,
            capital=capital,
        )
        engine.add_strategy(MonthlyMinMarketValueStrategy, {"initial_capital": capital, "current_month": start.month})

        engine.load_data()
        engine.run_backtesting()
        df = engine.calculate_result()
        dfs.append(df)
        
        record_df_dicts[i][symbol["symbol"]] = df
        record_candle_dicts[i][symbol["symbol"]] = engine.history_data
        res = engine.calculate_statistics(output=False)
        engine.cross_stop_order
        print(f"策略回测成功：{symbol['symbol']}，总净利润：{res['total_net_pnl']}")
        month_profits.append(res["total_net_pnl"])
        record_engines.append(copy.deepcopy(engine))
        
        data.add_tech_data(vt_symbol, 'daily_df', df)
        data.add_trade_data(vt_symbol, convert_list_to_df(engine.get_all_trades()))
        if res["total_net_pnl"] > 0:
            goods_symbols.append({"symbol": symbol["symbol"], "total_net_pnl": res["total_net_pnl"]})
    month_profit = sum(month_profits)
    print(f"{start.year}-{start.month}月总净利润：{month_profit}")
    total_profits.append(month_profit)

integrated_df = sum_specified_keep_others(dfs, sum_columns=['trade_count', 'turnover', 'commission', 'slippage', 'trading_pnl', 'holding_pnl', 'total_pnl', 'net_pnl'])
engine = BacktestingEngine()
intergrated_result = engine.calculate_statistics(integrated_df, output=False, capital=10000000)
print(f"总净利润：{sum(total_profits)}")
# Out:
# [datetime.datetime(2024, 4, 1, 0, 0), datetime.datetime(2024, 5, 1, 0, 0), datetime.datetime(2024, 6, 1, 0, 0), datetime.datetime(2024, 7, 1, 0, 0), datetime.datetime(2024, 8, 1, 0, 0), datetime.datetime(2024, 9, 1, 0, 0), datetime.datetime(2024, 10, 1, 0, 0), datetime.datetime(2024, 11, 1, 0, 0), datetime.datetime(2024, 12, 1, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 2, 1, 0, 0), datetime.datetime(2025, 3, 1, 0, 0)]
# 开始日期: 2024-04-01 00:00:00
# 候选标的：[{'symbol': '002856', 'name': '美芝股份', 'market_value': 1165043208.0}, {'symbol': '002633', 'name': '申科股份', 'market_value': 1219500000.0}, {'symbol': '002193', 'name': '如意集团', 'market_value': 1219594472.32}, {'symbol': '002629', 'name': '仁智股份', 'market_value': 1231347360.0}, {'symbol': '001211', 'name': '双枪科技', 'market_value': 1250640000.0}, {'symbol': '002652', 'name': '扬子新材', 'market_value': 1341607680.0}, {'symbol': '000692', 'name': '惠天热电', 'market_value': 1406679014.4}, {'symbol': '000953', 'name': '河化股份', 'market_value': 1424215389.1200001}, {'symbol': '002247', 'name': '聚力文化', 'market_value': 1429461734.3999999}, {'symbol': '002207', 'name': '准油股份', 'market_value': 1454407336.8}]
# 正在使用mysql数据库
# 2025-07-30 23:29:23.978642	历史数据加载完成，数据量：45
# symbol: 002856, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 919.0, 目标价格: 10.87
# 订单状态更新: Status.ALLTRADED, 价格: 11.8, 数量: 919.0
# symbol: 002856, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 919.0, 目标仓位: 0, 目标价格: 9.39
# 订单状态更新: Status.ALLTRADED, 价格: 8.4, 数量: 919.0
# symbol: 002856, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.93
# 2025-07-30 23:29:23.990719	逐日盯市盈亏计算完成
# 2025-07-30 23:29:23.990800	开始计算策略统计指标
# 2025-07-30 23:29:24.000669	策略统计指标计算完成
# 策略回测成功：002856，总净利润：-148934.35308000012
# 2025-07-30 23:29:24.031085	历史数据加载完成，数据量：45
# symbol: 002633, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 784.0, 目标价格: 12.74
# 订单状态更新: Status.ALLTRADED, 价格: 13.8, 数量: 784.0
# symbol: 002633, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 784.0, 目标仓位: 0, 目标价格: 11.02
# 订单状态更新: Status.ALLTRADED, 价格: 10.0, 数量: 784.0
# symbol: 002633, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.91
# 2025-07-30 23:29:24.033100	逐日盯市盈亏计算完成
# 2025-07-30 23:29:24.033124	开始计算策略统计指标
# 2025-07-30 23:29:24.036500	策略统计指标计算完成
# 策略回测成功：002633，总净利润：-172536.07168000008
# 2025-07-30 23:29:24.051292	历史数据加载完成，数据量：45
# symbol: 002193, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 948.0, 目标价格: 10.54
# 订单状态更新: Status.ALLTRADED, 价格: 11.6, 数量: 948.0
# symbol: 002193, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 948.0, 目标仓位: 0, 目标价格: 8.98
# 订单状态更新: Status.ALLTRADED, 价格: 8.0, 数量: 948.0
# symbol: 002193, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.86
# 2025-07-30 23:29:24.053043	逐日盯市盈亏计算完成
# 2025-07-30 23:29:24.053066	开始计算策略统计指标
# 2025-07-30 23:29:24.056045	策略统计指标计算完成
# 策略回测成功：002193，总净利润：-182071.40111999994
# 2025-07-30 23:29:24.069976	历史数据加载完成，数据量：45
# symbol: 002629, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 892.0, 目标价格: 11.2
# 订单状态更新: Status.ALLTRADED, 价格: 12.2, 数量: 892.0
# symbol: 002629, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 892.0, 目标仓位: 0, 目标价格: 9.58
# 订单状态更新: Status.ALLTRADED, 价格: 8.6, 数量: 892.0
# symbol: 002629, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.21
# 2025-07-30 23:29:24.071623	逐日盯市盈亏计算完成
# 2025-07-30 23:29:24.071643	开始计算策略统计指标
# 2025-07-30 23:29:24.074461	策略统计指标计算完成
# 策略回测成功：002629，总净利润：-173995.7945999999
# 2025-07-30 23:29:24.087472	历史数据加载完成，数据量：45
# symbol: 001211, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 526.0, 目标价格: 19.0
# 订单状态更新: Status.ALLTRADED, 价格: 20.0, 数量: 526.0
# symbol: 001211, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 526.0, 目标仓位: 0, 目标价格: 18.91
# 订单状态更新: Status.ALLTRADED, 价格: 18.0, 数量: 526.0
# symbol: 001211, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 17.19
# 2025-07-30 23:29:24.089559	逐日盯市盈亏计算完成
# 2025-07-30 23:29:24.089582	开始计算策略统计指标
# 2025-07-30 23:29:24.092290	策略统计指标计算完成
# 策略回测成功：001211，总净利润：-25833.821979999993
# 2025-07-30 23:29:24.105762	历史数据加载完成，数据量：45
# symbol: 002652, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 715.0, 目标价格: 13.98
# 订单状态更新: Status.ALLTRADED, 价格: 15.0, 数量: 715.0
# symbol: 002652, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 715.0, 目标仓位: 0, 目标价格: 12.88
# 订单状态更新: Status.ALLTRADED, 价格: 11.8, 数量: 715.0
# symbol: 002652, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.68
# 2025-07-30 23:29:24.107403	逐日盯市盈亏计算完成
# 2025-07-30 23:29:24.107423	开始计算策略统计指标
# 2025-07-30 23:29:24.110045	策略统计指标计算完成
# 策略回测成功：002652，总净利润：-100157.61470000003
# 2025-07-30 23:29:24.125333	历史数据加载完成，数据量：44
# symbol: 000692, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 789.0, 目标价格: 12.66
# 订单状态更新: Status.ALLTRADED, 价格: 13.6, 数量: 789.0
# symbol: 000692, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 789.0, 目标仓位: 0, 目标价格: 14.21
# 订单状态更新: Status.ALLTRADED, 价格: 13.2, 数量: 789.0
# symbol: 000692, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 18.02
# 2025-07-30 23:29:24.127612	逐日盯市盈亏计算完成
# 2025-07-30 23:29:24.127634	开始计算策略统计指标
# 2025-07-30 23:29:24.130835	策略统计指标计算完成
# 策略回测成功：000692，总净利润：147480.53487
# 2025-07-30 23:29:24.147033	历史数据加载完成，数据量：45
# symbol: 000953, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 1184.0, 目标价格: 8.44
# 订单状态更新: Status.ALLTRADED, 价格: 9.4, 数量: 1184.0
# symbol: 000953, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 1184.0, 目标仓位: 0, 目标价格: 7.25
# 订单状态更新: Status.ALLTRADED, 价格: 6.2, 数量: 1184.0
# symbol: 000953, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.18
# 2025-07-30 23:29:24.148902	逐日盯市盈亏计算完成
# 2025-07-30 23:29:24.148929	开始计算策略统计指标
# 2025-07-30 23:29:24.152923	策略统计指标计算完成
# 策略回测成功：000953，总净利润：-176472.08608
# 2025-07-30 23:29:24.171259	历史数据加载完成，数据量：45
# symbol: 002247, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 730.0, 目标价格: 13.68
# 订单状态更新: Status.ALLTRADED, 价格: 14.6, 数量: 730.0
# symbol: 002247, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 730.0, 目标仓位: 0, 目标价格: 11.76
# 订单状态更新: Status.ALLTRADED, 价格: 10.8, 数量: 730.0
# symbol: 002247, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.22
# 2025-07-30 23:29:24.173050	逐日盯市盈亏计算完成
# 2025-07-30 23:29:24.173075	开始计算策略统计指标
# 2025-07-30 23:29:24.175930	策略统计指标计算完成
# 策略回测成功：002247，总净利润：-165035.58219999995
# 2025-07-30 23:29:24.190374	历史数据加载完成，数据量：45
# symbol: 002207, 日期: 2024-04-01 00:00:00+08:00, 当前资金: 1000000, 交易单位: 100, 目标仓位: 865.0, 目标价格: 11.56
# 订单状态更新: Status.ALLTRADED, 价格: 12.6, 数量: 865.0
# symbol: 002207, 日期: 2024-05-06 00:00:00+08:00, 交易单位: 865.0, 目标仓位: 0, 目标价格: 11.48
# 订单状态更新: Status.ALLTRADED, 价格: 10.4, 数量: 865.0
# symbol: 002207, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.34
# 2025-07-30 23:29:24.192095	逐日盯市盈亏计算完成
# 2025-07-30 23:29:24.192117	开始计算策略统计指标
# 2025-07-30 23:29:24.194772	策略统计指标计算完成
# 策略回测成功：002207，总净利润：-38119.99640000006
# 2024-4月总净利润：-1035676.1869700002
# 开始日期: 2024-05-01 00:00:00
# 候选标的：[{'symbol': '002856', 'name': '美芝股份', 'market_value': 1165043208.0}, {'symbol': '002633', 'name': '申科股份', 'market_value': 1219500000.0}, {'symbol': '002193', 'name': '如意集团', 'market_value': 1219594472.32}, {'symbol': '002629', 'name': '仁智股份', 'market_value': 1231347360.0}, {'symbol': '001211', 'name': '双枪科技', 'market_value': 1250640000.0}, {'symbol': '002652', 'name': '扬子新材', 'market_value': 1341607680.0}, {'symbol': '000692', 'name': '惠天热电', 'market_value': 1406679014.4}, {'symbol': '000953', 'name': '河化股份', 'market_value': 1424215389.1200001}, {'symbol': '002247', 'name': '聚力文化', 'market_value': 1429461734.3999999}, {'symbol': '002207', 'name': '准油股份', 'market_value': 1454407336.8}]
# 2025-07-30 23:29:33.270620	历史数据加载完成，数据量：46
# symbol: 002856, 日期: 2024-05-06 00:00:00+08:00, 当前资金: 896432.381303, 交易单位: 100, 目标仓位: 954.0, 目标价格: 9.39
# 订单状态更新: Status.ALLTRADED, 价格: 10.4, 数量: 954.0
# symbol: 002856, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 954.0, 目标仓位: 0, 目标价格: 9.93
# 订单状态更新: Status.ALLTRADED, 价格: 9.0, 数量: 954.0
# symbol: 002856, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.35
# 2025-07-30 23:29:33.276452	逐日盯市盈亏计算完成
# 2025-07-30 23:29:33.276510	开始计算策略统计指标
# 2025-07-30 23:29:33.282692	策略统计指标计算完成
# 策略回测成功：002856，总净利润：-26767.35107999989
# 2025-07-30 23:29:33.298327	历史数据加载完成，数据量：46
# symbol: 002633, 日期: 2024-05-06 00:00:00+08:00, 当前资金: 896432.381303, 交易单位: 100, 目标仓位: 813.0, 目标价格: 11.02
# 订单状态更新: Status.ALLTRADED, 价格: 12.0, 数量: 813.0
# symbol: 002633, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 813.0, 目标仓位: 0, 目标价格: 9.91
# 订单状态更新: Status.ALLTRADED, 价格: 9.0, 数量: 813.0
# symbol: 002633, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.99
# 2025-07-30 23:29:33.300589	逐日盯市盈亏计算完成
# 2025-07-30 23:29:33.300632	开始计算策略统计指标
# 2025-07-30 23:29:33.305192	策略统计指标计算完成
# 策略回测成功：002633，总净利润：-127691.90192999996
# 2025-07-30 23:29:33.317572	历史数据加载完成，数据量：46
# symbol: 002193, 日期: 2024-05-06 00:00:00+08:00, 当前资金: 896432.381303, 交易单位: 100, 目标仓位: 998.0, 目标价格: 8.98
# 订单状态更新: Status.ALLTRADED, 价格: 10.0, 数量: 998.0
# symbol: 002193, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 998.0, 目标仓位: 0, 目标价格: 7.86
# 订单状态更新: Status.ALLTRADED, 价格: 6.8, 数量: 998.0
# symbol: 002193, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.36
# 2025-07-30 23:29:33.319448	逐日盯市盈亏计算完成
# 2025-07-30 23:29:33.319480	开始计算策略统计指标
# 2025-07-30 23:29:33.323324	策略统计指标计算完成
# 策略回测成功：002193，总净利润：-161726.11956000005
# 2025-07-30 23:29:33.335481	历史数据加载完成，数据量：46
# symbol: 002629, 日期: 2024-05-06 00:00:00+08:00, 当前资金: 896432.381303, 交易单位: 100, 目标仓位: 935.0, 目标价格: 9.58
# 订单状态更新: Status.ALLTRADED, 价格: 10.6, 数量: 935.0
# symbol: 002629, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 935.0, 目标仓位: 0, 目标价格: 8.21
# 订单状态更新: Status.ALLTRADED, 价格: 7.2, 数量: 935.0
# symbol: 002629, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.16
# 2025-07-30 23:29:33.337353	逐日盯市盈亏计算完成
# 2025-07-30 23:29:33.337390	开始计算策略统计指标
# 2025-07-30 23:29:33.340313	策略统计指标计算完成
# 策略回测成功：002629，总净利润：-188919.59240000014
# 2025-07-30 23:29:33.350390	历史数据加载完成，数据量：46
# symbol: 001211, 日期: 2024-05-06 00:00:00+08:00, 当前资金: 896432.381303, 交易单位: 100, 目标仓位: 474.0, 目标价格: 18.91
# 订单状态更新: Status.ALLTRADED, 价格: 20.0, 数量: 474.0
# symbol: 001211, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 474.0, 目标仓位: 0, 目标价格: 17.19
# 订单状态更新: Status.ALLTRADED, 价格: 16.2, 数量: 474.0
# symbol: 001211, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 16.4
# 2025-07-30 23:29:33.352606	逐日盯市盈亏计算完成
# 2025-07-30 23:29:33.352630	开始计算策略统计指标
# 2025-07-30 23:29:33.355240	策略统计指标计算完成
# 策略回测成功：001211，总净利润：-114758.90759999998
# 2025-07-30 23:29:33.365372	历史数据加载完成，数据量：46
# symbol: 002652, 日期: 2024-05-06 00:00:00+08:00, 当前资金: 896432.381303, 交易单位: 100, 目标仓位: 695.0, 目标价格: 12.88
# 订单状态更新: Status.ALLTRADED, 价格: 13.8, 数量: 695.0
# symbol: 002652, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 695.0, 目标仓位: 0, 目标价格: 11.68
# 订单状态更新: Status.ALLTRADED, 价格: 10.6, 数量: 695.0
# symbol: 002652, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 13.84
# 2025-07-30 23:29:33.367180	逐日盯市盈亏计算完成
# 2025-07-30 23:29:33.367207	开始计算策略统计指标
# 2025-07-30 23:29:33.369760	策略统计指标计算完成
# 策略回测成功：002652，总净利润：-121676.10334999998
# 2025-07-30 23:29:33.380436	历史数据加载完成，数据量：45
# symbol: 000692, 日期: 2024-05-06 00:00:00+08:00, 当前资金: 896432.381303, 交易单位: 100, 目标仓位: 630.0, 目标价格: 14.21
# 订单状态更新: Status.ALLTRADED, 价格: 15.2, 数量: 630.0
# symbol: 000692, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 630.0, 目标仓位: 0, 目标价格: 18.02
# 订单状态更新: Status.ALLTRADED, 价格: 17.0, 数量: 630.0
# symbol: 000692, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 18.38
# 2025-07-30 23:29:33.382256	逐日盯市盈亏计算完成
# 2025-07-30 23:29:33.382279	开始计算策略统计指标
# 2025-07-30 23:29:33.384843	策略统计指标计算完成
# 策略回测成功：000692，总净利润：184529.53890000004
# 2025-07-30 23:29:33.395043	历史数据加载完成，数据量：46
# symbol: 000953, 日期: 2024-05-06 00:00:00+08:00, 当前资金: 896432.381303, 交易单位: 100, 目标仓位: 1236.0, 目标价格: 7.25
# 订单状态更新: Status.ALLTRADED, 价格: 8.2, 数量: 1236.0
# symbol: 000953, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 1236.0, 目标仓位: 0, 目标价格: 6.18
# 订单状态更新: Status.ALLTRADED, 价格: 5.2, 数量: 1236.0
# symbol: 000953, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 5.21
# 2025-07-30 23:29:33.396781	逐日盯市盈亏计算完成
# 2025-07-30 23:29:33.396810	开始计算策略统计指标
# 2025-07-30 23:29:33.399594	策略统计指标计算完成
# 策略回测成功：000953，总净利润：-203989.8726
# 2025-07-30 23:29:33.410010	历史数据加载完成，数据量：46
# symbol: 002247, 日期: 2024-05-06 00:00:00+08:00, 当前资金: 896432.381303, 交易单位: 100, 目标仓位: 762.0, 目标价格: 11.76
# 订单状态更新: Status.ALLTRADED, 价格: 12.8, 数量: 762.0
# symbol: 002247, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 762.0, 目标仓位: 0, 目标价格: 11.22
# 订单状态更新: Status.ALLTRADED, 价格: 10.2, 数量: 762.0
# symbol: 002247, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.98
# 2025-07-30 23:29:33.411843	逐日盯市盈亏计算完成
# 2025-07-30 23:29:33.411867	开始计算策略统计指标
# 2025-07-30 23:29:33.414623	策略统计指标计算完成
# 策略回测成功：002247，总净利润：-76252.39511999997
# 2025-07-30 23:29:33.424511	历史数据加载完成，数据量：46
# symbol: 002207, 日期: 2024-05-06 00:00:00+08:00, 当前资金: 896432.381303, 交易单位: 100, 目标仓位: 780.0, 目标价格: 11.48
# 订单状态更新: Status.ALLTRADED, 价格: 12.4, 数量: 780.0
# symbol: 002207, 日期: 2024-06-03 00:00:00+08:00, 交易单位: 780.0, 目标仓位: 0, 目标价格: 9.34
# 订单状态更新: Status.ALLTRADED, 价格: 8.4, 数量: 780.0
# symbol: 002207, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.82
# 2025-07-30 23:29:33.426196	逐日盯市盈亏计算完成
# 2025-07-30 23:29:33.426220	开始计算策略统计指标
# 2025-07-30 23:29:33.428771	策略统计指标计算完成
# 策略回测成功：002207，总净利润：-209088.67199999993
# 2024-5月总净利润：-1046341.3767399999
# 开始日期: 2024-06-01 00:00:00
# 候选标的：[{'symbol': '002856', 'name': '美芝股份', 'market_value': 1165043208.0}, {'symbol': '002633', 'name': '申科股份', 'market_value': 1219500000.0}, {'symbol': '002193', 'name': '如意集团', 'market_value': 1219594472.32}, {'symbol': '002629', 'name': '仁智股份', 'market_value': 1231347360.0}, {'symbol': '001211', 'name': '双枪科技', 'market_value': 1250640000.0}, {'symbol': '002652', 'name': '扬子新材', 'market_value': 1341607680.0}, {'symbol': '000692', 'name': '惠天热电', 'market_value': 1406679014.4}, {'symbol': '000953', 'name': '河化股份', 'market_value': 1424215389.1200001}, {'symbol': '002247', 'name': '聚力文化', 'market_value': 1429461734.3999999}, {'symbol': '002207', 'name': '准油股份', 'market_value': 1454407336.8}]
# 2025-07-30 23:29:42.533685	历史数据加载完成，数据量：49
# symbol: 002856, 日期: 2024-06-03 00:00:00+08:00, 当前资金: 791798.243629, 交易单位: 100, 目标仓位: 797.0, 目标价格: 9.93
# 订单状态更新: Status.ALLTRADED, 价格: 11.0, 数量: 797.0
# symbol: 002856, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 797.0, 目标仓位: 0, 目标价格: 11.35
# 订单状态更新: Status.ALLTRADED, 价格: 10.4, 数量: 797.0
# symbol: 002856, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.01
# 2025-07-30 23:29:42.539046	逐日盯市盈亏计算完成
# 2025-07-30 23:29:42.539092	开始计算策略统计指标
# 2025-07-30 23:29:42.543954	策略统计指标计算完成
# 策略回测成功：002856，总净利润：93198.71727000005
# 2025-07-30 23:29:42.560651	历史数据加载完成，数据量：49
# symbol: 002633, 日期: 2024-06-03 00:00:00+08:00, 当前资金: 791798.243629, 交易单位: 100, 目标仓位: 798.0, 目标价格: 9.91
# 订单状态更新: Status.ALLTRADED, 价格: 11.0, 数量: 798.0
# symbol: 002633, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 798.0, 目标仓位: 0, 目标价格: 8.99
# 订单状态更新: Status.ALLTRADED, 价格: 8.0, 数量: 798.0
# symbol: 002633, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.54
# 2025-07-30 23:29:42.562607	逐日盯市盈亏计算完成
# 2025-07-30 23:29:42.562643	开始计算策略统计指标
# 2025-07-30 23:29:42.565875	策略统计指标计算完成
# 策略回测成功：002633，总净利润：-100593.10295999993
# 2025-07-30 23:29:42.581202	历史数据加载完成，数据量：49
# symbol: 002193, 日期: 2024-06-03 00:00:00+08:00, 当前资金: 791798.243629, 交易单位: 100, 目标仓位: 1007.0, 目标价格: 7.86
# 订单状态更新: Status.ALLTRADED, 价格: 8.8, 数量: 1007.0
# symbol: 002193, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 1007.0, 目标仓位: 0, 目标价格: 6.36
# 订单状态更新: Status.ALLTRADED, 价格: 5.4, 数量: 1007.0
# symbol: 002193, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.9
# 2025-07-30 23:29:42.583071	逐日盯市盈亏计算完成
# 2025-07-30 23:29:42.583102	开始计算策略统计指标
# 2025-07-30 23:29:42.585825	策略统计指标计算完成
# 策略回测成功：002193，总净利润：-173246.89819999994
# 2025-07-30 23:29:42.600970	历史数据加载完成，数据量：49
# symbol: 002629, 日期: 2024-06-03 00:00:00+08:00, 当前资金: 791798.243629, 交易单位: 100, 目标仓位: 964.0, 目标价格: 8.21
# 订单状态更新: Status.ALLTRADED, 价格: 9.2, 数量: 964.0
# symbol: 002629, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 964.0, 目标仓位: 0, 目标价格: 6.16
# 订单状态更新: Status.ALLTRADED, 价格: 5.2, 数量: 964.0
# symbol: 002629, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.84
# 2025-07-30 23:29:42.602717	逐日盯市盈亏计算完成
# 2025-07-30 23:29:42.602743	开始计算策略统计指标
# 2025-07-30 23:29:42.606080	策略统计指标计算完成
# 策略回测成功：002629，总净利润：-215977.12423999992
# 2025-07-30 23:29:42.620295	历史数据加载完成，数据量：49
# symbol: 001211, 日期: 2024-06-03 00:00:00+08:00, 当前资金: 791798.243629, 交易单位: 100, 目标仓位: 460.0, 目标价格: 17.19
# 订单状态更新: Status.ALLTRADED, 价格: 18.2, 数量: 460.0
# symbol: 001211, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 460.0, 目标仓位: 0, 目标价格: 16.4
# 订单状态更新: Status.ALLTRADED, 价格: 15.4, 数量: 460.0
# symbol: 001211, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 16.44
# 2025-07-30 23:29:42.622032	逐日盯市盈亏计算完成
# 2025-07-30 23:29:42.622063	开始计算策略统计指标
# 2025-07-30 23:29:42.624786	策略统计指标计算完成
# 策略回测成功：001211，总净利润：-41905.91260000008
# 2025-07-30 23:29:42.638773	历史数据加载完成，数据量：49
# symbol: 002652, 日期: 2024-06-03 00:00:00+08:00, 当前资金: 791798.243629, 交易单位: 100, 目标仓位: 677.0, 目标价格: 11.68
# 订单状态更新: Status.ALLTRADED, 价格: 12.6, 数量: 677.0
# symbol: 002652, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 677.0, 目标仓位: 0, 目标价格: 13.84
# 订单状态更新: Status.ALLTRADED, 价格: 12.8, 数量: 677.0
# symbol: 002652, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 14.65
# 2025-07-30 23:29:42.640626	逐日盯市盈亏计算完成
# 2025-07-30 23:29:42.640656	开始计算策略统计指标
# 2025-07-30 23:29:42.643230	策略统计指标计算完成
# 策略回测成功：002652，总净利润：122485.47352999992
# 2025-07-30 23:29:42.658488	历史数据加载完成，数据量：49
# symbol: 000692, 日期: 2024-06-03 00:00:00+08:00, 当前资金: 791798.243629, 交易单位: 100, 目标仓位: 439.0, 目标价格: 18.02
# 订单状态更新: Status.ALLTRADED, 价格: 19.0, 数量: 439.0
# symbol: 000692, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 439.0, 目标仓位: 0, 目标价格: 18.38
# 订单状态更新: Status.ALLTRADED, 价格: 17.4, 数量: 439.0
# symbol: 000692, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 17.9
# 2025-07-30 23:29:42.660330	逐日盯市盈亏计算完成
# 2025-07-30 23:29:42.660357	开始计算策略统计指标
# 2025-07-30 23:29:42.663016	策略统计指标计算完成
# 策略回测成功：000692，总净利润：8732.693360000121
# 2025-07-30 23:29:42.678625	历史数据加载完成，数据量：49
# symbol: 000953, 日期: 2024-06-03 00:00:00+08:00, 当前资金: 791798.243629, 交易单位: 100, 目标仓位: 1281.0, 目标价格: 6.18
# 订单状态更新: Status.ALLTRADED, 价格: 7.2, 数量: 1281.0
# symbol: 000953, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 1281.0, 目标仓位: 0, 目标价格: 5.21
# 订单状态更新: Status.ALLTRADED, 价格: 4.2, 数量: 1281.0
# symbol: 000953, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.8
# 2025-07-30 23:29:42.680454	逐日盯市盈亏计算完成
# 2025-07-30 23:29:42.680479	开始计算策略统计指标
# 2025-07-30 23:29:42.683175	策略统计指标计算完成
# 策略回测成功：000953，总净利润：-162730.5411899999
# 2025-07-30 23:29:42.699639	历史数据加载完成，数据量：49
# symbol: 002247, 日期: 2024-06-03 00:00:00+08:00, 当前资金: 791798.243629, 交易单位: 100, 目标仓位: 705.0, 目标价格: 11.22
# 订单状态更新: Status.ALLTRADED, 价格: 12.2, 数量: 705.0
# symbol: 002247, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 705.0, 目标仓位: 0, 目标价格: 10.98
# 订单状态更新: Status.ALLTRADED, 价格: 10.0, 数量: 705.0
# symbol: 002247, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.88
# 2025-07-30 23:29:42.701645	逐日盯市盈亏计算完成
# 2025-07-30 23:29:42.701676	开始计算策略统计指标
# 2025-07-30 23:29:42.704504	策略统计指标计算完成
# 策略回测成功：002247，总净利润：-40936.82609999998
# 2025-07-30 23:29:42.723395	历史数据加载完成，数据量：49
# symbol: 002207, 日期: 2024-06-03 00:00:00+08:00, 当前资金: 791798.243629, 交易单位: 100, 目标仓位: 847.0, 目标价格: 9.34
# 订单状态更新: Status.ALLTRADED, 价格: 10.4, 数量: 847.0
# symbol: 002207, 日期: 2024-07-01 00:00:00+08:00, 交易单位: 847.0, 目标仓位: 0, 目标价格: 8.82
# 订单状态更新: Status.ALLTRADED, 价格: 7.8, 数量: 847.0
# symbol: 002207, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.7
# 2025-07-30 23:29:42.725271	逐日盯市盈亏计算完成
# 2025-07-30 23:29:42.725302	开始计算策略统计指标
# 2025-07-30 23:29:42.728092	策略统计指标计算完成
# 策略回测成功：002207，总净利润：-67806.04292000002
# 2024-6月总净利润：-578779.5640499997
# 开始日期: 2024-07-01 00:00:00
# 候选标的：[{'symbol': '002629', 'name': '仁智股份', 'market_value': 676804400.0}, {'symbol': '002193', 'name': '如意集团', 'market_value': 727569234.56}, {'symbol': '002052', 'name': '同洲电子', 'market_value': 775798067.2}, {'symbol': '000679', 'name': '大连友谊', 'market_value': 844668000.0}, {'symbol': '000953', 'name': '河化股份', 'market_value': 853064744.64}, {'symbol': '002633', 'name': '申科股份', 'market_value': 882000000.0}, {'symbol': '000506', 'name': '中润资源', 'market_value': 938307969.92}, {'symbol': '002719', 'name': '麦趣尔', 'market_value': 1036129763.2}, {'symbol': '002072', 'name': '凯瑞德', 'market_value': 1036857600.0}, {'symbol': '000890', 'name': '法尔胜', 'market_value': 1040369840.64}]
# 2025-07-30 23:29:52.442666	历史数据加载完成，数据量：51
# symbol: 002629, 日期: 2024-07-01 00:00:00+08:00, 当前资金: 733920.2872240001, 交易单位: 100, 目标仓位: 1191.0, 目标价格: 6.16
# 订单状态更新: Status.ALLTRADED, 价格: 7.2, 数量: 1191.0
# symbol: 002629, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 1191.0, 目标仓位: 0, 目标价格: 6.84
# 订单状态更新: Status.ALLTRADED, 价格: 5.8, 数量: 1191.0
# symbol: 002629, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.95
# 2025-07-30 23:29:52.458256	逐日盯市盈亏计算完成
# 2025-07-30 23:29:52.458319	开始计算策略统计指标
# 2025-07-30 23:29:52.467111	策略统计指标计算完成
# 策略回测成功：002629，总净利润：26155.55099999992
# 2025-07-30 23:29:52.483227	历史数据加载完成，数据量：51
# symbol: 002193, 日期: 2024-07-01 00:00:00+08:00, 当前资金: 733920.2872240001, 交易单位: 100, 目标仓位: 1153.0, 目标价格: 6.36
# 订单状态更新: Status.ALLTRADED, 价格: 7.4, 数量: 1153.0
# symbol: 002193, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 1153.0, 目标仓位: 0, 目标价格: 7.9
# 订单状态更新: Status.ALLTRADED, 价格: 6.8, 数量: 1153.0
# symbol: 002193, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.38
# 2025-07-30 23:29:52.485049	逐日盯市盈亏计算完成
# 2025-07-30 23:29:52.485074	开始计算策略统计指标
# 2025-07-30 23:29:52.487876	策略统计指标计算完成
# 策略回测成功：002193，总净利润：115250.60547999994
# 2025-07-30 23:29:52.672896	历史数据加载完成，数据量：51
# symbol: 002052, 日期: 2024-07-01 00:00:00+08:00, 当前资金: 733920.2872240001, 交易单位: 100, 目标仓位: 982.0, 目标价格: 7.47
# 订单状态更新: Status.ALLTRADED, 价格: 8.4, 数量: 982.0
# symbol: 002052, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 982.0, 目标仓位: 0, 目标价格: 9.9
# 订单状态更新: Status.ALLTRADED, 价格: 8.8, 数量: 982.0
# symbol: 002052, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 17.27
# 2025-07-30 23:29:52.675117	逐日盯市盈亏计算完成
# 2025-07-30 23:29:52.675154	开始计算策略统计指标
# 2025-07-30 23:29:52.678066	策略统计指标计算完成
# 策略回测成功：002052，总净利润：199295.24042
# 2025-07-30 23:29:52.699238	历史数据加载完成，数据量：51
# symbol: 000679, 日期: 2024-07-01 00:00:00+08:00, 当前资金: 733920.2872240001, 交易单位: 100, 目标仓位: 456.0, 目标价格: 16.07
# 订单状态更新: Status.ALLTRADED, 价格: 17.0, 数量: 456.0
# symbol: 000679, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 456.0, 目标仓位: 0, 目标价格: 18.91
# 订单状态更新: Status.ALLTRADED, 价格: 18.0, 数量: 456.0
# symbol: 000679, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 18.54
# 2025-07-30 23:29:52.701537	逐日盯市盈亏计算完成
# 2025-07-30 23:29:52.701570	开始计算策略统计指标
# 2025-07-30 23:29:52.704593	策略统计指标计算完成
# 策略回测成功：000679，总净利润：113040.33887999995
# 2025-07-30 23:29:52.723660	历史数据加载完成，数据量：51
# symbol: 000953, 日期: 2024-07-01 00:00:00+08:00, 当前资金: 733920.2872240001, 交易单位: 100, 目标仓位: 1408.0, 目标价格: 5.21
# 订单状态更新: Status.ALLTRADED, 价格: 6.2, 数量: 1408.0
# symbol: 000953, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 1408.0, 目标仓位: 0, 目标价格: 7.8
# 订单状态更新: Status.ALLTRADED, 价格: 6.8, 数量: 1408.0
# symbol: 000953, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.27
# 2025-07-30 23:29:52.726012	逐日盯市盈亏计算完成
# 2025-07-30 23:29:52.726037	开始计算策略统计指标
# 2025-07-30 23:29:52.728770	策略统计指标计算完成
# 策略回测成功：000953，总净利润：378694.76479999995
# 2025-07-30 23:29:52.748105	历史数据加载完成，数据量：51
# symbol: 002633, 日期: 2024-07-01 00:00:00+08:00, 当前资金: 733920.2872240001, 交易单位: 100, 目标仓位: 816.0, 目标价格: 8.99
# 订单状态更新: Status.ALLTRADED, 价格: 10.0, 数量: 816.0
# symbol: 002633, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 816.0, 目标仓位: 0, 目标价格: 10.54
# 订单状态更新: Status.ALLTRADED, 价格: 9.6, 数量: 816.0
# symbol: 002633, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.51
# 2025-07-30 23:29:52.750692	逐日盯市盈亏计算完成
# 2025-07-30 23:29:52.750725	开始计算策略统计指标
# 2025-07-30 23:29:52.753550	策略统计指标计算完成
# 策略回测成功：002633，总净利润：91344.26399999997
# 2025-07-30 23:29:52.772087	历史数据加载完成，数据量：51
# symbol: 000506, 日期: 2024-07-01 00:00:00+08:00, 当前资金: 733920.2872240001, 交易单位: 100, 目标仓位: 5733.0, 目标价格: 1.28
# 订单状态更新: Status.ALLTRADED, 价格: 2.2, 数量: 5733.0
# symbol: 000506, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 5733.0, 目标仓位: 0, 目标价格: 2.57
# 订单状态更新: Status.ALLTRADED, 价格: 1.6, 数量: 5733.0
# symbol: 000506, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 2.51
# 2025-07-30 23:29:52.774169	逐日盯市盈亏计算完成
# 2025-07-30 23:29:52.774201	开始计算策略统计指标
# 2025-07-30 23:29:52.776935	策略统计指标计算完成
# 策略回测成功：000506，总净利润：601899.8157900001
# 2025-07-30 23:29:52.794219	历史数据加载完成，数据量：51
# symbol: 002719, 日期: 2024-07-01 00:00:00+08:00, 当前资金: 733920.2872240001, 交易单位: 100, 目标仓位: 726.0, 目标价格: 10.1
# 订单状态更新: Status.ALLTRADED, 价格: 11.2, 数量: 726.0
# symbol: 002719, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 726.0, 目标仓位: 0, 目标价格: 10.42
# 订单状态更新: Status.ALLTRADED, 价格: 9.4, 数量: 726.0
# symbol: 002719, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.0
# 2025-07-30 23:29:52.796094	逐日盯市盈亏计算完成
# 2025-07-30 23:29:52.796125	开始计算策略统计指标
# 2025-07-30 23:29:52.798784	策略统计指标计算完成
# 策略回测成功：002719，总净利润：-23276.736119999998
# 2025-07-30 23:29:52.814896	历史数据加载完成，数据量：51
# symbol: 002072, 日期: 2024-07-01 00:00:00+08:00, 当前资金: 733920.2872240001, 交易单位: 100, 目标仓位: 2300.0, 目标价格: 3.19
# 订单状态更新: Status.ALLTRADED, 价格: 4.2, 数量: 2300.0
# symbol: 002072, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 2300.0, 目标仓位: 0, 目标价格: 3.43
# 订单状态更新: Status.ALLTRADED, 价格: 2.4, 数量: 2300.0
# symbol: 002072, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 4.78
# 2025-07-30 23:29:52.817362	逐日盯市盈亏计算完成
# 2025-07-30 23:29:52.817394	开始计算策略统计指标
# 2025-07-30 23:29:52.820121	策略统计指标计算完成
# 策略回测成功：002072，总净利润：-50645.81599999997
# 2025-07-30 23:29:52.838590	历史数据加载完成，数据量：51
# symbol: 000890, 日期: 2024-07-01 00:00:00+08:00, 当前资金: 733920.2872240001, 交易单位: 100, 目标仓位: 1595.0, 目标价格: 4.6
# 订单状态更新: Status.ALLTRADED, 价格: 5.6, 数量: 1595.0
# symbol: 000890, 日期: 2024-08-01 00:00:00+08:00, 交易单位: 1595.0, 目标仓位: 0, 目标价格: 4.89
# 订单状态更新: Status.ALLTRADED, 价格: 3.8, 数量: 1595.0
# symbol: 000890, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 4.77
# 2025-07-30 23:29:52.840877	逐日盯市盈亏计算完成
# 2025-07-30 23:29:52.840909	开始计算策略统计指标
# 2025-07-30 23:29:52.843730	策略统计指标计算完成
# 策略回测成功：000890，总净利润：-22374.979000000007
# 2024-7月总净利润：1429383.04925
# 开始日期: 2024-08-01 00:00:00
# 候选标的：[{'symbol': '002629', 'name': '仁智股份', 'market_value': 676804400.0}, {'symbol': '002193', 'name': '如意集团', 'market_value': 727569234.56}, {'symbol': '002052', 'name': '同洲电子', 'market_value': 775798067.2}, {'symbol': '000679', 'name': '大连友谊', 'market_value': 844668000.0}, {'symbol': '000953', 'name': '河化股份', 'market_value': 853064744.64}, {'symbol': '002633', 'name': '申科股份', 'market_value': 882000000.0}, {'symbol': '000506', 'name': '中润资源', 'market_value': 938307969.92}, {'symbol': '002719', 'name': '麦趣尔', 'market_value': 1036129763.2}, {'symbol': '002072', 'name': '凯瑞德', 'market_value': 1036857600.0}, {'symbol': '000890', 'name': '法尔胜', 'market_value': 1040369840.64}]
# 2025-07-30 23:30:02.784060	历史数据加载完成，数据量：43
# symbol: 002629, 日期: 2024-08-01 00:00:00+08:00, 当前资金: 876858.5921490001, 交易单位: 100, 目标仓位: 1281.0, 目标价格: 6.84
# 订单状态更新: Status.ALLTRADED, 价格: 7.8, 数量: 1281.0
# symbol: 002629, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 1281.0, 目标仓位: 0, 目标价格: 6.95
# 订单状态更新: Status.ALLTRADED, 价格: 6.0, 数量: 1281.0
# symbol: 002629, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.61
# 2025-07-30 23:30:02.800526	逐日盯市盈亏计算完成
# 2025-07-30 23:30:02.802262	开始计算策略统计指标
# 2025-07-30 23:30:02.817402	策略统计指标计算完成
# 策略回测成功：002629，总净利润：-28235.03339999992
# 2025-07-30 23:30:02.838929	历史数据加载完成，数据量：43
# symbol: 002193, 日期: 2024-08-01 00:00:00+08:00, 当前资金: 876858.5921490001, 交易单位: 100, 目标仓位: 1109.0, 目标价格: 7.9
# 订单状态更新: Status.ALLTRADED, 价格: 8.8, 数量: 1109.0
# symbol: 002193, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 1109.0, 目标仓位: 0, 目标价格: 8.38
# 订单状态更新: Status.ALLTRADED, 价格: 7.4, 数量: 1109.0
# symbol: 002193, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.9
# 2025-07-30 23:30:02.841141	逐日盯市盈亏计算完成
# 2025-07-30 23:30:02.841184	开始计算策略统计指标
# 2025-07-30 23:30:02.844127	策略统计指标计算完成
# 策略回测成功：002193，总净利润：24343.769900000094
# 2025-07-30 23:30:02.860174	历史数据加载完成，数据量：43
# symbol: 002052, 日期: 2024-08-01 00:00:00+08:00, 当前资金: 876858.5921490001, 交易单位: 100, 目标仓位: 885.0, 目标价格: 9.9
# 订单状态更新: Status.ALLTRADED, 价格: 10.8, 数量: 885.0
# symbol: 002052, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 885.0, 目标仓位: 0, 目标价格: 17.27
# 订单状态更新: Status.ALLTRADED, 价格: 16.2, 数量: 885.0
# symbol: 002052, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 14.16
# 2025-07-30 23:30:02.862355	逐日盯市盈亏计算完成
# 2025-07-30 23:30:02.862390	开始计算策略统计指标
# 2025-07-30 23:30:02.869830	策略统计指标计算完成
# 策略回测成功：002052，总净利润：694650.8989499998
# 2025-07-30 23:30:02.885022	历史数据加载完成，数据量：43
# symbol: 000679, 日期: 2024-08-01 00:00:00+08:00, 当前资金: 876858.5921490001, 交易单位: 100, 目标仓位: 463.0, 目标价格: 18.91
# 订单状态更新: Status.ALLTRADED, 价格: 20.0, 数量: 463.0
# symbol: 000679, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 463.0, 目标仓位: 0, 目标价格: 18.54
# 订单状态更新: Status.ALLTRADED, 价格: 17.6, 数量: 463.0
# symbol: 000679, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 23.27
# 2025-07-30 23:30:02.886991	逐日盯市盈亏计算完成
# 2025-07-30 23:30:02.887024	开始计算策略统计指标
# 2025-07-30 23:30:02.889926	策略统计指标计算完成
# 策略回测成功：000679，总净利润：-29684.059719999932
# 2025-07-30 23:30:02.907957	历史数据加载完成，数据量：43
# symbol: 000953, 日期: 2024-08-01 00:00:00+08:00, 当前资金: 876858.5921490001, 交易单位: 100, 目标仓位: 1124.0, 目标价格: 7.8
# 订单状态更新: Status.ALLTRADED, 价格: 8.8, 数量: 1124.0
# symbol: 000953, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 1124.0, 目标仓位: 0, 目标价格: 7.27
# 订单状态更新: Status.ALLTRADED, 价格: 6.2, 数量: 1124.0
# symbol: 000953, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.65
# 2025-07-30 23:30:02.910426	逐日盯市盈亏计算完成
# 2025-07-30 23:30:02.910470	开始计算策略统计指标
# 2025-07-30 23:30:02.917655	策略统计指标计算完成
# 策略回测成功：000953，总净利润：-160784.63692
# 2025-07-30 23:30:03.010121	历史数据加载完成，数据量：43
# symbol: 002633, 日期: 2024-08-01 00:00:00+08:00, 当前资金: 876858.5921490001, 交易单位: 100, 目标仓位: 831.0, 目标价格: 10.54
# 订单状态更新: Status.ALLTRADED, 价格: 11.6, 数量: 831.0
# symbol: 002633, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 831.0, 目标仓位: 0, 目标价格: 11.51
# 订单状态更新: Status.ALLTRADED, 价格: 10.6, 数量: 831.0
# symbol: 002633, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 13.76
# 2025-07-30 23:30:03.012837	逐日盯市盈亏计算完成
# 2025-07-30 23:30:03.012878	开始计算策略统计指标
# 2025-07-30 23:30:03.016280	策略统计指标计算完成
# 策略回测成功：002633，总净利润：66424.60554000009
# 2025-07-30 23:30:03.038019	历史数据加载完成，数据量：41
# symbol: 000506, 日期: 2024-08-01 00:00:00+08:00, 当前资金: 876858.5921490001, 交易单位: 100, 目标仓位: 3411.0, 目标价格: 2.57
# 订单状态更新: Status.ALLTRADED, 价格: 3.6, 数量: 3411.0
# symbol: 000506, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 3411.0, 目标仓位: 0, 目标价格: 2.51
# 订单状态更新: Status.ALLTRADED, 价格: 1.6, 数量: 3411.0
# 2025-07-30 23:30:03.040619	逐日盯市盈亏计算完成
# 2025-07-30 23:30:03.040655	开始计算策略统计指标
# 2025-07-30 23:30:03.043423	策略统计指标计算完成
# 策略回测成功：000506，总净利润：-109206.43956
# 2025-07-30 23:30:03.063916	历史数据加载完成，数据量：43
# symbol: 002719, 日期: 2024-08-01 00:00:00+08:00, 当前资金: 876858.5921490001, 交易单位: 100, 目标仓位: 841.0, 目标价格: 10.42
# 订单状态更新: Status.ALLTRADED, 价格: 11.4, 数量: 841.0
# symbol: 002719, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 841.0, 目标仓位: 0, 目标价格: 10.0
# 订单状态更新: Status.ALLTRADED, 价格: 9.0, 数量: 841.0
# symbol: 002719, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.99
# 2025-07-30 23:30:03.065766	逐日盯市盈亏计算完成
# 2025-07-30 23:30:03.065797	开始计算策略统计指标
# 2025-07-30 23:30:03.068389	策略统计指标计算完成
# 策略回测成功：002719，总净利润：-49670.54489000012
# 2025-07-30 23:30:03.089117	历史数据加载完成，数据量：43
# symbol: 002072, 日期: 2024-08-01 00:00:00+08:00, 当前资金: 876858.5921490001, 交易单位: 100, 目标仓位: 2556.0, 目标价格: 3.43
# 订单状态更新: Status.ALLTRADED, 价格: 4.4, 数量: 2556.0
# symbol: 002072, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 2556.0, 目标仓位: 0, 目标价格: 4.78
# 订单状态更新: Status.ALLTRADED, 价格: 3.8, 数量: 2556.0
# symbol: 002072, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 5.84
# 2025-07-30 23:30:03.091383	逐日盯市盈亏计算完成
# 2025-07-30 23:30:03.091408	开始计算策略统计指标
# 2025-07-30 23:30:03.093949	策略统计指标计算完成
# 策略回测成功：002072，总净利润：250425.1223999999
# 2025-07-30 23:30:03.114410	历史数据加载完成，数据量：43
# symbol: 000890, 日期: 2024-08-01 00:00:00+08:00, 当前资金: 876858.5921490001, 交易单位: 100, 目标仓位: 1793.0, 目标价格: 4.89
# 订单状态更新: Status.ALLTRADED, 价格: 5.8, 数量: 1793.0
# symbol: 000890, 日期: 2024-09-02 00:00:00+08:00, 交易单位: 1793.0, 目标仓位: 0, 目标价格: 4.77
# 订单状态更新: Status.ALLTRADED, 价格: 3.8, 数量: 1793.0
# symbol: 000890, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.56
# 2025-07-30 23:30:03.116965	逐日盯市盈亏计算完成
# 2025-07-30 23:30:03.116999	开始计算策略统计指标
# 2025-07-30 23:30:03.119704	策略统计指标计算完成
# 策略回测成功：000890，总净利润：-82529.63840000011
# 2024-8月总净利润：575734.0438999999
# 开始日期: 2024-09-01 00:00:00
# 候选标的：[{'symbol': '002629', 'name': '仁智股份', 'market_value': 676804400.0}, {'symbol': '002193', 'name': '如意集团', 'market_value': 727569234.56}, {'symbol': '002052', 'name': '同洲电子', 'market_value': 775798067.2}, {'symbol': '000679', 'name': '大连友谊', 'market_value': 844668000.0}, {'symbol': '000953', 'name': '河化股份', 'market_value': 853064744.64}, {'symbol': '002633', 'name': '申科股份', 'market_value': 882000000.0}, {'symbol': '000506', 'name': '中润资源', 'market_value': 938307969.92}, {'symbol': '002719', 'name': '麦趣尔', 'market_value': 1036129763.2}, {'symbol': '002072', 'name': '凯瑞德', 'market_value': 1036857600.0}, {'symbol': '000890', 'name': '法尔胜', 'market_value': 1040369840.64}]
# 2025-07-30 23:30:12.346876	历史数据加载完成，数据量：43
# symbol: 002629, 日期: 2024-09-02 00:00:00+08:00, 当前资金: 934431.9965390002, 交易单位: 100, 目标仓位: 1344.0, 目标价格: 6.95
# 订单状态更新: Status.ALLTRADED, 价格: 8.0, 数量: 1344.0
# symbol: 002629, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 1344.0, 目标仓位: 0, 目标价格: 9.61
# 订单状态更新: Status.ALLTRADED, 价格: 8.6, 数量: 1344.0
# symbol: 002629, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.37
# 2025-07-30 23:30:12.353264	逐日盯市盈亏计算完成
# 2025-07-30 23:30:12.353322	开始计算策略统计指标
# 2025-07-30 23:30:12.358943	策略统计指标计算完成
# 策略回测成功：002629，总净利润：249918.52031999995
# 2025-07-30 23:30:12.376619	历史数据加载完成，数据量：43
# symbol: 002193, 日期: 2024-09-02 00:00:00+08:00, 当前资金: 934431.9965390002, 交易单位: 100, 目标仓位: 1115.0, 目标价格: 8.38
# 订单状态更新: Status.ALLTRADED, 价格: 9.4, 数量: 1115.0
# symbol: 002193, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 1115.0, 目标仓位: 0, 目标价格: 10.9
# 订单状态更新: Status.ALLTRADED, 价格: 10.0, 数量: 1115.0
# symbol: 002193, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.46
# 2025-07-30 23:30:12.379024	逐日盯市盈亏计算完成
# 2025-07-30 23:30:12.379089	开始计算策略统计指标
# 2025-07-30 23:30:12.383405	策略统计指标计算完成
# 策略回测成功：002193，总净利润：216245.57529999997
# 2025-07-30 23:30:12.399133	历史数据加载完成，数据量：43
# symbol: 002052, 日期: 2024-09-02 00:00:00+08:00, 当前资金: 934431.9965390002, 交易单位: 100, 目标仓位: 541.0, 目标价格: 17.27
# 订单状态更新: Status.ALLTRADED, 价格: 18.2, 数量: 541.0
# symbol: 002052, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 541.0, 目标仓位: 0, 目标价格: 14.16
# 订单状态更新: Status.ALLTRADED, 价格: 13.2, 数量: 541.0
# symbol: 002052, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 22.34
# 2025-07-30 23:30:12.400986	逐日盯市盈亏计算完成
# 2025-07-30 23:30:12.401025	开始计算策略统计指标
# 2025-07-30 23:30:12.404154	策略统计指标计算完成
# 策略回测成功：002052，总净利润：-211583.99094999992
# 2025-07-30 23:30:12.418902	历史数据加载完成，数据量：43
# symbol: 000679, 日期: 2024-09-02 00:00:00+08:00, 当前资金: 934431.9965390002, 交易单位: 100, 目标仓位: 504.0, 目标价格: 18.54
# 订单状态更新: Status.ALLTRADED, 价格: 19.6, 数量: 504.0
# symbol: 000679, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 504.0, 目标仓位: 0, 目标价格: 23.27
# 订单状态更新: Status.ALLTRADED, 价格: 22.2, 数量: 504.0
# symbol: 000679, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 22.77
# 2025-07-30 23:30:12.420757	逐日盯市盈亏计算完成
# 2025-07-30 23:30:12.420793	开始计算策略统计指标
# 2025-07-30 23:30:12.423630	策略统计指标计算完成
# 策略回测成功：000679，总净利润：205568.91936
# 2025-07-30 23:30:12.437173	历史数据加载完成，数据量：43
# symbol: 000953, 日期: 2024-09-02 00:00:00+08:00, 当前资金: 934431.9965390002, 交易单位: 100, 目标仓位: 1285.0, 目标价格: 7.27
# 订单状态更新: Status.ALLTRADED, 价格: 8.2, 数量: 1285.0
# symbol: 000953, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 1285.0, 目标仓位: 0, 目标价格: 9.65
# 订单状态更新: Status.ALLTRADED, 价格: 8.6, 数量: 1285.0
# symbol: 000953, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.98
# 2025-07-30 23:30:12.438871	逐日盯市盈亏计算完成
# 2025-07-30 23:30:12.438903	开始计算策略统计指标
# 2025-07-30 23:30:12.441759	策略统计指标计算完成
# 策略回测成功：000953，总净利润：246654.8504999999
# 2025-07-30 23:30:12.456366	历史数据加载完成，数据量：43
# symbol: 002633, 日期: 2024-09-02 00:00:00+08:00, 当前资金: 934431.9965390002, 交易单位: 100, 目标仓位: 811.0, 目标价格: 11.51
# 订单状态更新: Status.ALLTRADED, 价格: 12.6, 数量: 811.0
# symbol: 002633, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 811.0, 目标仓位: 0, 目标价格: 13.76
# 订单状态更新: Status.ALLTRADED, 价格: 12.8, 数量: 811.0
# symbol: 002633, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 19.01
# 2025-07-30 23:30:12.458176	逐日盯市盈亏计算完成
# 2025-07-30 23:30:12.458211	开始计算策略统计指标
# 2025-07-30 23:30:12.460886	策略统计指标计算完成
# 策略回测成功：002633，总净利润：123210.34778000001
# 2025-07-30 23:30:12.475358	历史数据加载完成，数据量：38
# symbol: 000506, 日期: 2024-09-02 00:00:00+08:00, 当前资金: 934431.9965390002, 交易单位: 100, 目标仓位: 3722.0, 目标价格: 2.51
# 订单状态更新: Status.ALLTRADED, 价格: 3.6, 数量: 3722.0
# symbol: 000506, 日期: 2024-10-15 00:00:00+08:00, 交易单位: 3722.0, 目标仓位: 0, 目标价格: 2.78
# 订单状态更新: Status.ALLTRADED, 价格: 1.8, 数量: 3722.0
# symbol: 000506, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.42
# 2025-07-30 23:30:12.477096	逐日盯市盈亏计算完成
# 2025-07-30 23:30:12.477128	开始计算策略统计指标
# 2025-07-30 23:30:12.479747	策略统计指标计算完成
# 策略回测成功：000506，总净利润：-37283.646200000134
# 2025-07-30 23:30:12.494225	历史数据加载完成，数据量：43
# symbol: 002719, 日期: 2024-09-02 00:00:00+08:00, 当前资金: 934431.9965390002, 交易单位: 100, 目标仓位: 934.0, 目标价格: 10.0
# 订单状态更新: Status.ALLTRADED, 价格: 11.0, 数量: 934.0
# symbol: 002719, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 934.0, 目标仓位: 0, 目标价格: 11.99
# 订单状态更新: Status.ALLTRADED, 价格: 11.0, 数量: 934.0
# symbol: 002719, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 13.54
# 2025-07-30 23:30:12.496507	逐日盯市盈亏计算完成
# 2025-07-30 23:30:12.496581	开始计算策略统计指标
# 2025-07-30 23:30:12.499305	策略统计指标计算完成
# 策略回测成功：002719，总净利润：108282.91640000005
# 2025-07-30 23:30:12.513785	历史数据加载完成，数据量：43
# symbol: 002072, 日期: 2024-09-02 00:00:00+08:00, 当前资金: 934431.9965390002, 交易单位: 100, 目标仓位: 1954.0, 目标价格: 4.78
# 订单状态更新: Status.ALLTRADED, 价格: 5.8, 数量: 1954.0
# symbol: 002072, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 1954.0, 目标仓位: 0, 目标价格: 5.84
# 订单状态更新: Status.ALLTRADED, 价格: 4.8, 数量: 1954.0
# symbol: 002072, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 5.18
# 2025-07-30 23:30:12.528509	逐日盯市盈亏计算完成
# 2025-07-30 23:30:12.528546	开始计算策略统计指标
# 2025-07-30 23:30:12.532173	策略统计指标计算完成
# 策略回测成功：002072，总净利润：113270.09727999993
# 2025-07-30 23:30:12.546393	历史数据加载完成，数据量：43
# symbol: 000890, 日期: 2024-09-02 00:00:00+08:00, 当前资金: 934431.9965390002, 交易单位: 100, 目标仓位: 1958.0, 目标价格: 4.77
# 订单状态更新: Status.ALLTRADED, 价格: 5.8, 数量: 1958.0
# symbol: 000890, 日期: 2024-10-08 00:00:00+08:00, 交易单位: 1958.0, 目标仓位: 0, 目标价格: 7.56
# 订单状态更新: Status.ALLTRADED, 价格: 6.6, 数量: 1958.0
# symbol: 000890, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.24
# 2025-07-30 23:30:12.548251	逐日盯市盈亏计算完成
# 2025-07-30 23:30:12.548289	开始计算策略统计指标
# 2025-07-30 23:30:12.550922	策略统计指标计算完成
# 策略回测成功：000890，总净利润：405235.4532600001
# 2024-9月总净利润：1419519.0430499997
# 开始日期: 2024-10-01 00:00:00
# 候选标的：[{'symbol': '002629', 'name': '仁智股份', 'market_value': 1004290399.9999999}, {'symbol': '002856', 'name': '美芝股份', 'market_value': 1215108944.0}, {'symbol': '002719', 'name': '麦趣尔', 'market_value': 1220717586.56}, {'symbol': '001211', 'name': '双枪科技', 'market_value': 1230480000.0}, {'symbol': '002193', 'name': '如意集团', 'market_value': 1253617494.08}, {'symbol': '002141', 'name': '贤丰控股', 'market_value': 1280840401.92}, {'symbol': '002633', 'name': '申科股份', 'market_value': 1347000000.0}, {'symbol': '000506', 'name': '中润资源', 'market_value': 1347075798.3999999}, {'symbol': '002494', 'name': '华斯股份', 'market_value': 1365864806.4}, {'symbol': '000890', 'name': '法尔胜', 'market_value': 1405338292.8}]
# 2025-07-30 23:30:21.650390	历史数据加载完成，数据量：45
# symbol: 002629, 日期: 2024-10-08 00:00:00+08:00, 当前资金: 1076383.9008440003, 交易单位: 100, 目标仓位: 1120.0, 目标价格: 9.61
# 订单状态更新: Status.ALLTRADED, 价格: 10.6, 数量: 1120.0
# symbol: 002629, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 1120.0, 目标仓位: 0, 目标价格: 10.37
# 订单状态更新: Status.ALLTRADED, 价格: 9.4, 数量: 1120.0
# symbol: 002629, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 12.78
# 2025-07-30 23:30:21.657011	逐日盯市盈亏计算完成
# 2025-07-30 23:30:21.657070	开始计算策略统计指标
# 2025-07-30 23:30:21.662832	策略统计指标计算完成
# 策略回测成功：002629，总净利润：76094.21119999999
# 2025-07-30 23:30:21.690161	历史数据加载完成，数据量：45
# symbol: 002856, 日期: 2024-10-08 00:00:00+08:00, 当前资金: 1076383.9008440003, 交易单位: 100, 目标仓位: 897.0, 目标价格: 11.99
# 订单状态更新: Status.ALLTRADED, 价格: 13.0, 数量: 897.0
# symbol: 002856, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 897.0, 目标仓位: 0, 目标价格: 11.26
# 订单状态更新: Status.ALLTRADED, 价格: 10.2, 数量: 897.0
# symbol: 002856, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 12.75
# 2025-07-30 23:30:21.692242	逐日盯市盈亏计算完成
# 2025-07-30 23:30:21.692287	开始计算策略统计指标
# 2025-07-30 23:30:21.695826	策略统计指标计算完成
# 策略回测成功：002856，总净利润：-92453.29665000006
# 2025-07-30 23:30:21.707121	历史数据加载完成，数据量：45
# symbol: 002719, 日期: 2024-10-08 00:00:00+08:00, 当前资金: 1076383.9008440003, 交易单位: 100, 目标仓位: 897.0, 目标价格: 11.99
# 订单状态更新: Status.ALLTRADED, 价格: 13.0, 数量: 897.0
# symbol: 002719, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 897.0, 目标仓位: 0, 目标价格: 13.54
# 订单状态更新: Status.ALLTRADED, 价格: 12.6, 数量: 897.0
# symbol: 002719, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 15.83
# 2025-07-30 23:30:21.708993	逐日盯市盈亏计算完成
# 2025-07-30 23:30:21.709030	开始计算策略统计指标
# 2025-07-30 23:30:21.712066	策略统计指标计算完成
# 策略回测成功：002719，总净利润：182918.57219999997
# 2025-07-30 23:30:21.726911	历史数据加载完成，数据量：45
# symbol: 001211, 日期: 2024-10-08 00:00:00+08:00, 当前资金: 1076383.9008440003, 交易单位: 100, 目标仓位: 565.0, 目标价格: 19.04
# 订单状态更新: Status.ALLTRADED, 价格: 20.0, 数量: 565.0
# symbol: 001211, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 565.0, 目标仓位: 0, 目标价格: 18.3
# 订单状态更新: Status.ALLTRADED, 价格: 17.2, 数量: 565.0
# symbol: 001211, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 21.8
# 2025-07-30 23:30:21.728620	逐日盯市盈亏计算完成
# 2025-07-30 23:30:21.728647	开始计算策略统计指标
# 2025-07-30 23:30:21.731434	策略统计指标计算完成
# 策略回测成功：001211，总净利润：-51477.86755000005
# 2025-07-30 23:30:21.742420	历史数据加载完成，数据量：45
# symbol: 002193, 日期: 2024-10-08 00:00:00+08:00, 当前资金: 1076383.9008440003, 交易单位: 100, 目标仓位: 987.0, 目标价格: 10.9
# 订单状态更新: Status.ALLTRADED, 价格: 12.0, 数量: 987.0
# symbol: 002193, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 987.0, 目标仓位: 0, 目标价格: 10.46
# 订单状态更新: Status.ALLTRADED, 价格: 9.4, 数量: 987.0
# symbol: 002193, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 13.78
# 2025-07-30 23:30:21.744136	逐日盯市盈亏计算完成
# 2025-07-30 23:30:21.744166	开始计算策略统计指标
# 2025-07-30 23:30:21.746740	策略统计指标计算完成
# 策略回测成功：002193，总净利润：-80996.71397999997
# 2025-07-30 23:30:21.760735	历史数据加载完成，数据量：45
# symbol: 002141, 日期: 2024-10-08 00:00:00+08:00, 当前资金: 1076383.9008440003, 交易单位: 100, 目标仓位: 1065.0, 目标价格: 10.1
# 订单状态更新: Status.ALLTRADED, 价格: 11.2, 数量: 1065.0
# symbol: 002141, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 1065.0, 目标仓位: 0, 目标价格: 11.82
# 订单状态更新: Status.ALLTRADED, 价格: 10.8, 数量: 1065.0
# symbol: 002141, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 12.37
# 2025-07-30 23:30:21.762456	逐日盯市盈亏计算完成
# 2025-07-30 23:30:21.762482	开始计算策略统计指标
# 2025-07-30 23:30:21.765183	策略统计指标计算完成
# 策略回测成功：002141，总净利润：107495.95605000002
# 2025-07-30 23:30:21.775692	历史数据加载完成，数据量：45
# symbol: 002633, 日期: 2024-10-08 00:00:00+08:00, 当前资金: 1076383.9008440003, 交易单位: 100, 目标仓位: 782.0, 目标价格: 13.76
# 订单状态更新: Status.ALLTRADED, 价格: 14.8, 数量: 782.0
# symbol: 002633, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 782.0, 目标仓位: 0, 目标价格: 19.01
# 订单状态更新: Status.ALLTRADED, 价格: 18.0, 数量: 782.0
# symbol: 002633, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 20.15
# 2025-07-30 23:30:21.777366	逐日盯市盈亏计算完成
# 2025-07-30 23:30:21.777396	开始计算策略统计指标
# 2025-07-30 23:30:21.779955	策略统计指标计算完成
# 策略回测成功：002633，总净利润：310379.79601999995
# 2025-07-30 23:30:21.790644	历史数据加载完成，数据量：40
# symbol: 000506, 日期: 2024-10-15 00:00:00+08:00, 当前资金: 1076383.9008440003, 交易单位: 100, 目标仓位: 3871.0, 目标价格: 2.78
# 订单状态更新: Status.ALLTRADED, 价格: 3.8, 数量: 3871.0
# symbol: 000506, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 3871.0, 目标仓位: 0, 目标价格: 6.42
# 订单状态更新: Status.ALLTRADED, 价格: 5.4, 数量: 3871.0
# symbol: 000506, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 7.71
# 2025-07-30 23:30:21.792562	逐日盯市盈亏计算完成
# 2025-07-30 23:30:21.792593	开始计算策略统计指标
# 2025-07-30 23:30:21.795262	策略统计指标计算完成
# 策略回测成功：000506，总净利润：1312155.3087300002
# 2025-07-30 23:30:21.809646	历史数据加载完成，数据量：45
# symbol: 002494, 日期: 2024-10-08 00:00:00+08:00, 当前资金: 1076383.9008440003, 交易单位: 100, 目标仓位: 1023.0, 目标价格: 10.52
# 订单状态更新: Status.ALLTRADED, 价格: 11.6, 数量: 1023.0
# symbol: 002494, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 1023.0, 目标仓位: 0, 目标价格: 10.6
# 订单状态更新: Status.ALLTRADED, 价格: 9.6, 数量: 1023.0
# symbol: 002494, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 12.21
# 2025-07-30 23:30:21.811340	逐日盯市盈亏计算完成
# 2025-07-30 23:30:21.811371	开始计算策略统计指标
# 2025-07-30 23:30:21.814097	策略统计指标计算完成
# 策略回测成功：002494，总净利润：-12340.203480000084
# 2025-07-30 23:30:21.824527	历史数据加载完成，数据量：45
# symbol: 000890, 日期: 2024-10-08 00:00:00+08:00, 当前资金: 1076383.9008440003, 交易单位: 100, 目标仓位: 1423.0, 目标价格: 7.56
# 订单状态更新: Status.ALLTRADED, 价格: 8.6, 数量: 1423.0
# symbol: 000890, 日期: 2024-11-01 00:00:00+08:00, 交易单位: 1423.0, 目标仓位: 0, 目标价格: 7.24
# 订单状态更新: Status.ALLTRADED, 价格: 6.2, 数量: 1423.0
# symbol: 000890, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.4
# 2025-07-30 23:30:21.826314	逐日盯市盈亏计算完成
# 2025-07-30 23:30:21.826347	开始计算策略统计指标
# 2025-07-30 23:30:21.828948	策略统计指标计算完成
# 策略回测成功：000890，总净利润：-48444.071260000055
# 2024-10月总净利润：1703331.6912799997
# 开始日期: 2024-11-01 00:00:00
# 候选标的：[{'symbol': '002629', 'name': '仁智股份', 'market_value': 1004290399.9999999}, {'symbol': '002856', 'name': '美芝股份', 'market_value': 1215108944.0}, {'symbol': '002719', 'name': '麦趣尔', 'market_value': 1220717586.56}, {'symbol': '001211', 'name': '双枪科技', 'market_value': 1230480000.0}, {'symbol': '002193', 'name': '如意集团', 'market_value': 1253617494.08}, {'symbol': '002141', 'name': '贤丰控股', 'market_value': 1280840401.92}, {'symbol': '002633', 'name': '申科股份', 'market_value': 1347000000.0}, {'symbol': '000506', 'name': '中润资源', 'market_value': 1347075798.3999999}, {'symbol': '002494', 'name': '华斯股份', 'market_value': 1365864806.4}, {'symbol': '000890', 'name': '法尔胜', 'market_value': 1405338292.8}]
# 2025-07-30 23:30:30.910683	历史数据加载完成，数据量：49
# symbol: 002629, 日期: 2024-11-01 00:00:00+08:00, 当前资金: 1246717.0699720003, 交易单位: 100, 目标仓位: 1202.0, 目标价格: 10.37
# 订单状态更新: Status.ALLTRADED, 价格: 11.4, 数量: 1202.0
# symbol: 002629, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 1202.0, 目标仓位: 0, 目标价格: 12.78
# 订单状态更新: Status.ALLTRADED, 价格: 11.8, 数量: 1202.0
# 2025-07-30 23:30:30.917409	逐日盯市盈亏计算完成
# 2025-07-30 23:30:30.917477	开始计算策略统计指标
# 2025-07-30 23:30:30.923643	策略统计指标计算完成
# 策略回测成功：002629，总净利润：254740.41291999992
# 2025-07-30 23:30:30.942805	历史数据加载完成，数据量：49
# symbol: 002856, 日期: 2024-11-01 00:00:00+08:00, 当前资金: 1246717.0699720003, 交易单位: 100, 目标仓位: 1107.0, 目标价格: 11.26
# 订单状态更新: Status.ALLTRADED, 价格: 12.2, 数量: 1107.0
# symbol: 002856, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 1107.0, 目标仓位: 0, 目标价格: 12.75
# 订单状态更新: Status.ALLTRADED, 价格: 11.8, 数量: 1107.0
# 2025-07-30 23:30:30.945245	逐日盯市盈亏计算完成
# 2025-07-30 23:30:30.945300	开始计算策略统计指标
# 2025-07-30 23:30:30.949527	策略统计指标计算完成
# 策略回测成功：002856，总净利润：140508.66501
# 2025-07-30 23:30:30.966776	历史数据加载完成，数据量：49
# symbol: 002719, 日期: 2024-11-01 00:00:00+08:00, 当前资金: 1246717.0699720003, 交易单位: 100, 目标仓位: 920.0, 目标价格: 13.54
# 订单状态更新: Status.ALLTRADED, 价格: 14.6, 数量: 920.0
# symbol: 002719, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 920.0, 目标仓位: 0, 目标价格: 15.83
# 订单状态更新: Status.ALLTRADED, 价格: 14.8, 数量: 920.0
# 2025-07-30 23:30:30.968854	逐日盯市盈亏计算完成
# 2025-07-30 23:30:30.968900	开始计算策略统计指标
# 2025-07-30 23:30:30.972290	策略统计指标计算完成
# 策略回测成功：002719，总净利润：83638.44200000004
# 2025-07-30 23:30:30.986915	历史数据加载完成，数据量：49
# symbol: 001211, 日期: 2024-11-01 00:00:00+08:00, 当前资金: 1246717.0699720003, 交易单位: 100, 目标仓位: 681.0, 目标价格: 18.3
# 订单状态更新: Status.ALLTRADED, 价格: 19.2, 数量: 681.0
# symbol: 001211, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 681.0, 目标仓位: 0, 目标价格: 21.8
# 订单状态更新: Status.ALLTRADED, 价格: 20.8, 数量: 681.0
# 2025-07-30 23:30:30.988835	逐日盯市盈亏计算完成
# 2025-07-30 23:30:30.988874	开始计算策略统计指标
# 2025-07-30 23:30:30.991616	策略统计指标计算完成
# 策略回测成功：001211，总净利润：213071.05527000007
# 2025-07-30 23:30:31.007503	历史数据加载完成，数据量：49
# symbol: 002193, 日期: 2024-11-01 00:00:00+08:00, 当前资金: 1246717.0699720003, 交易单位: 100, 目标仓位: 1191.0, 目标价格: 10.46
# 订单状态更新: Status.ALLTRADED, 价格: 11.4, 数量: 1191.0
# symbol: 002193, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 1191.0, 目标仓位: 0, 目标价格: 13.78
# 订单状态更新: Status.ALLTRADED, 价格: 12.8, 数量: 1191.0
# 2025-07-30 23:30:31.009273	逐日盯市盈亏计算完成
# 2025-07-30 23:30:31.009304	开始计算策略统计指标
# 2025-07-30 23:30:31.011885	策略统计指标计算完成
# 策略回测成功：002193，总净利润：509657.10288
# 2025-07-30 23:30:31.133135	历史数据加载完成，数据量：49
# symbol: 002141, 日期: 2024-11-01 00:00:00+08:00, 当前资金: 1246717.0699720003, 交易单位: 100, 目标仓位: 1054.0, 目标价格: 11.82
# 订单状态更新: Status.ALLTRADED, 价格: 12.8, 数量: 1054.0
# symbol: 002141, 日期: 2024-12-02 00:00:00+08:00, 交易单位: 1054.0, 目标仓位: 0, 目标价格: 12.37
# 订单状态更新: Status.ALLTRADED, 价格: 11.4, 数量: 1054.0
# 2025-07-30 23:30:31.135256	逐日盯市盈亏计算完成
# 2025-07-30 23:30:31.135300	开始计算策略统计指标
# 2025-07-30 23:30:31.138370	策略统计指标计算完成
# 策略回测成功：002141，总净利润：56840.23847999994
# 2025-07-30 23:30:31.171962	历史数据加载完成，数据量：49
# symbol: 002633, 日期: 2024-11-01 00:00:00+08:00, 当前资金: 1246717.0699720003, 交易单位: 100, 目标仓位: 655.0, 目标价格: 19.01
# 订单状态更新: Status.ALLTRADED, 价格: 20.0, 数量: 655.0
# ...
# 2025-07-30 23:30:49.901574	逐日盯市盈亏计算完成
# 2025-07-30 23:30:49.901609	开始计算策略统计指标
# 2025-07-30 23:30:49.904597	策略统计指标计算完成
# 策略回测成功：000890，总净利润：-114348.80927999996
# 2025-07-30 23:30:49.919720	历史数据加载完成，数据量：41
# symbol: 002719, 日期: 2025-01-02 00:00:00+08:00, 当前资金: 1399211.0136160003, 交易单位: 100, 目标仓位: 1068.0, 目标价格: 13.09
# 订单状态更新: Status.ALLTRADED, 价格: 14.0, 数量: 1068.0
# symbol: 002719, 日期: 2025-02-05 00:00:00+08:00, 交易单位: 1068.0, 目标仓位: 0, 目标价格: 12.18
# 订单状态更新: Status.ALLTRADED, 价格: 11.2, 数量: 1068.0
# symbol: 002719, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 12.92
# 2025-07-30 23:30:49.921445	逐日盯市盈亏计算完成
# 2025-07-30 23:30:49.921478	开始计算策略统计指标
# 2025-07-30 23:30:49.924139	策略统计指标计算完成
# 策略回测成功：002719，总净利润：-147464.86895999988
# 2025-07-30 23:30:49.937823	历史数据加载完成，数据量：41
# symbol: 001211, 日期: 2025-01-02 00:00:00+08:00, 当前资金: 1399211.0136160003, 交易单位: 100, 目标仓位: 669.0, 目标价格: 20.91
# 订单状态更新: Status.ALLTRADED, 价格: 22.0, 数量: 669.0
# symbol: 001211, 日期: 2025-02-05 00:00:00+08:00, 交易单位: 669.0, 目标仓位: 0, 目标价格: 23.4
# 订单状态更新: Status.ALLTRADED, 价格: 22.4, 数量: 669.0
# symbol: 001211, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 22.92
# 2025-07-30 23:30:49.939541	逐日盯市盈亏计算完成
# 2025-07-30 23:30:49.939570	开始计算策略统计指标
# 2025-07-30 23:30:49.942120	策略统计指标计算完成
# 策略回测成功：001211，总净利润：131703.90926999983
# 2025-07-30 23:30:49.955773	历史数据加载完成，数据量：41
# symbol: 001336, 日期: 2025-01-02 00:00:00+08:00, 当前资金: 1399211.0136160003, 交易单位: 100, 目标仓位: 788.0, 目标价格: 17.74
# 订单状态更新: Status.ALLTRADED, 价格: 18.8, 数量: 788.0
# symbol: 001336, 日期: 2025-02-05 00:00:00+08:00, 交易单位: 788.0, 目标仓位: 0, 目标价格: 19.23
# 订单状态更新: Status.ALLTRADED, 价格: 18.2, 数量: 788.0
# symbol: 001336, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 19.21
# 2025-07-30 23:30:49.957447	逐日盯市盈亏计算完成
# 2025-07-30 23:30:49.957474	开始计算策略统计指标
# 2025-07-30 23:30:49.960020	策略统计指标计算完成
# 策略回测成功：001336，总净利润：91320.20104000019
# 2025-07-30 23:30:49.974349	历史数据加载完成，数据量：41
# symbol: 002921, 日期: 2025-01-02 00:00:00+08:00, 当前资金: 1399211.0136160003, 交易单位: 100, 目标仓位: 854.0, 目标价格: 16.38
# 订单状态更新: Status.ALLTRADED, 价格: 17.4, 数量: 854.0
# symbol: 002921, 日期: 2025-02-05 00:00:00+08:00, 交易单位: 854.0, 目标仓位: 0, 目标价格: 18.04
# 订单状态更新: Status.ALLTRADED, 价格: 17.0, 数量: 854.0
# symbol: 002921, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 18.68
# 2025-07-30 23:30:49.976055	逐日盯市盈亏计算完成
# 2025-07-30 23:30:49.976084	开始计算策略统计指标
# 2025-07-30 23:30:49.978602	策略统计指标计算完成
# 策略回测成功：002921，总净利润：92997.3804199999
# 2025-07-30 23:30:49.992568	历史数据加载完成，数据量：41
# symbol: 002652, 日期: 2025-01-02 00:00:00+08:00, 当前资金: 1399211.0136160003, 交易单位: 100, 目标仓位: 951.0, 目标价格: 14.7
# 订单状态更新: Status.ALLTRADED, 价格: 15.6, 数量: 951.0
# symbol: 002652, 日期: 2025-02-05 00:00:00+08:00, 交易单位: 951.0, 目标仓位: 0, 目标价格: 15.23
# 订单状态更新: Status.ALLTRADED, 价格: 14.2, 数量: 951.0
# symbol: 002652, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 15.28
# 2025-07-30 23:30:49.994294	逐日盯市盈亏计算完成
# 2025-07-30 23:30:49.994322	开始计算策略统计指标
# 2025-07-30 23:30:49.996893	策略统计指标计算完成
# 策略回测成功：002652，总净利润：25591.210289999988
# 2025-07-30 23:30:50.011569	历史数据加载完成，数据量：41
# symbol: 002910, 日期: 2025-01-02 00:00:00+08:00, 当前资金: 1399211.0136160003, 交易单位: 100, 目标仓位: 1817.0, 目标价格: 7.7
# 订单状态更新: Status.ALLTRADED, 价格: 8.8, 数量: 1817.0
# symbol: 002910, 日期: 2025-02-05 00:00:00+08:00, 交易单位: 1817.0, 目标仓位: 0, 目标价格: 7.67
# 订单状态更新: Status.ALLTRADED, 价格: 6.6, 数量: 1817.0
# symbol: 002910, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.99
# 2025-07-30 23:30:50.013495	逐日盯市盈亏计算完成
# 2025-07-30 23:30:50.013524	开始计算策略统计指标
# 2025-07-30 23:30:50.016521	策略统计指标计算完成
# 策略回测成功：002910，总净利润：-74580.78187000012
# 2025-07-30 23:30:50.032014	历史数据加载完成，数据量：41
# symbol: 002188, 日期: 2025-01-02 00:00:00+08:00, 当前资金: 1399211.0136160003, 交易单位: 100, 目标仓位: 1561.0, 目标价格: 8.96
# 订单状态更新: Status.ALLTRADED, 价格: 10.0, 数量: 1561.0
# symbol: 002188, 日期: 2025-02-05 00:00:00+08:00, 交易单位: 1561.0, 目标仓位: 0, 目标价格: 8.88
# 订单状态更新: Status.ALLTRADED, 价格: 7.8, 数量: 1561.0
# symbol: 002188, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 9.39
# 2025-07-30 23:30:50.033926	逐日盯市盈亏计算完成
# 2025-07-30 23:30:50.033959	开始计算策略统计指标
# 2025-07-30 23:30:50.036755	策略统计指标计算完成
# 策略回测成功：002188，总净利润：-87500.85596000002
# 2025-1月总净利润：-111965.01391000023
# 开始日期: 2025-02-01 00:00:00
# 候选标的：[{'symbol': '002856', 'name': '美芝股份', 'market_value': 1247584016.0}, {'symbol': '002207', 'name': '准油股份', 'market_value': 1291933003.6799998}, {'symbol': '000890', 'name': '法尔胜', 'market_value': 1329827578.56}, {'symbol': '002719', 'name': '麦趣尔', 'market_value': 1363511940.48}, {'symbol': '001211', 'name': '双枪科技', 'market_value': 1396800000.0}, {'symbol': '001336', 'name': '楚环科技', 'market_value': 1412966200.32}, {'symbol': '002921', 'name': '联诚精密', 'market_value': 1431889076.6399999}, {'symbol': '002652', 'name': '扬子新材', 'market_value': 1444020480.0}, {'symbol': '002910', 'name': '庄园牧场', 'market_value': 1472411260.32}, {'symbol': '002188', 'name': '中天服务', 'market_value': 1475238462.72}]
# 2025-07-30 23:30:59.225032	历史数据加载完成，数据量：45
# symbol: 002856, 日期: 2025-02-05 00:00:00+08:00, 当前资金: 1388014.5122250002, 交易单位: 100, 目标仓位: 1261.0, 目标价格: 11.0
# 订单状态更新: Status.ALLTRADED, 价格: 12.0, 数量: 1261.0
# symbol: 002856, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 1261.0, 目标仓位: 0, 目标价格: 10.76
# 订单状态更新: Status.ALLTRADED, 价格: 9.8, 数量: 1261.0
# symbol: 002856, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 10.36
# 2025-07-30 23:30:59.229393	逐日盯市盈亏计算完成
# 2025-07-30 23:30:59.229433	开始计算策略统计指标
# 2025-07-30 23:30:59.233239	策略统计指标计算完成
# 策略回测成功：002856，总净利润：-104745.73420999997
# 2025-07-30 23:30:59.248462	历史数据加载完成，数据量：45
# symbol: 002207, 日期: 2025-02-05 00:00:00+08:00, 当前资金: 1388014.5122250002, 交易单位: 100, 目标仓位: 1278.0, 目标价格: 10.86
# 订单状态更新: Status.ALLTRADED, 价格: 11.8, 数量: 1278.0
# symbol: 002207, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 1278.0, 目标仓位: 0, 目标价格: 11.56
# 订单状态更新: Status.ALLTRADED, 价格: 10.6, 数量: 1278.0
# symbol: 002207, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 12.26
# 2025-07-30 23:30:59.250365	逐日盯市盈亏计算完成
# 2025-07-30 23:30:59.250410	开始计算策略统计指标
# 2025-07-30 23:30:59.254038	策略统计指标计算完成
# 策略回测成功：002207，总净利润：33142.19508000005
# 2025-07-30 23:30:59.269090	历史数据加载完成，数据量：45
# symbol: 000890, 日期: 2025-02-05 00:00:00+08:00, 当前资金: 1388014.5122250002, 交易单位: 100, 目标仓位: 2119.0, 目标价格: 6.55
# 订单状态更新: Status.ALLTRADED, 价格: 7.6, 数量: 2119.0
# symbol: 000890, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 2119.0, 目标仓位: 0, 目标价格: 7.9
# 订单状态更新: Status.ALLTRADED, 价格: 6.8, 数量: 2119.0
# symbol: 000890, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 6.93
# 2025-07-30 23:30:59.270857	逐日盯市盈亏计算完成
# 2025-07-30 23:30:59.270892	开始计算策略统计指标
# 2025-07-30 23:30:59.273915	策略统计指标计算完成
# 策略回测成功：000890，总净利润：152476.84062
# 2025-07-30 23:30:59.289953	历史数据加载完成，数据量：45
# symbol: 002719, 日期: 2025-02-05 00:00:00+08:00, 当前资金: 1388014.5122250002, 交易单位: 100, 目标仓位: 1139.0, 目标价格: 12.18
# 订单状态更新: Status.ALLTRADED, 价格: 13.2, 数量: 1139.0
# symbol: 002719, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 1139.0, 目标仓位: 0, 目标价格: 12.92
# 订单状态更新: Status.ALLTRADED, 价格: 12.0, 数量: 1139.0
# symbol: 002719, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 11.81
# 2025-07-30 23:30:59.291826	逐日盯市盈亏计算完成
# 2025-07-30 23:30:59.291863	开始计算策略统计指标
# 2025-07-30 23:30:59.294636	策略统计指标计算完成
# 策略回测成功：002719，总净利润：29528.84835999981
# 2025-07-30 23:30:59.308598	历史数据加载完成，数据量：45
# symbol: 001211, 日期: 2025-02-05 00:00:00+08:00, 当前资金: 1388014.5122250002, 交易单位: 100, 目标仓位: 593.0, 目标价格: 23.4
# 订单状态更新: Status.ALLTRADED, 价格: 24.4, 数量: 593.0
# symbol: 001211, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 593.0, 目标仓位: 0, 目标价格: 22.92
# 订单状态更新: Status.ALLTRADED, 价格: 22.0, 数量: 593.0
# symbol: 001211, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 22.67
# 2025-07-30 23:30:59.310274	逐日盯市盈亏计算完成
# 2025-07-30 23:30:59.310305	开始计算策略统计指标
# 2025-07-30 23:30:59.312956	策略统计指标计算完成
# 策略回测成功：001211，总净利润：-50487.38548999996
# 2025-07-30 23:30:59.327118	历史数据加载完成，数据量：45
# symbol: 001336, 日期: 2025-02-05 00:00:00+08:00, 当前资金: 1388014.5122250002, 交易单位: 100, 目标仓位: 721.0, 目标价格: 19.23
# 订单状态更新: Status.ALLTRADED, 价格: 20.2, 数量: 721.0
# symbol: 001336, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 721.0, 目标仓位: 0, 目标价格: 19.21
# 订单状态更新: Status.ALLTRADED, 价格: 18.2, 数量: 721.0
# symbol: 001336, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 24.21
# 2025-07-30 23:30:59.328795	逐日盯市盈亏计算完成
# 2025-07-30 23:30:59.328826	开始计算策略统计指标
# 2025-07-30 23:30:59.331504	策略统计指标计算完成
# 策略回测成功：001336，总净利润：-44785.23224000017
# 2025-07-30 23:30:59.345273	历史数据加载完成，数据量：45
# symbol: 002921, 日期: 2025-02-05 00:00:00+08:00, 当前资金: 1388014.5122250002, 交易单位: 100, 目标仓位: 769.0, 目标价格: 18.04
# 订单状态更新: Status.ALLTRADED, 价格: 19.0, 数量: 769.0
# symbol: 002921, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 769.0, 目标仓位: 0, 目标价格: 18.68
# 订单状态更新: Status.ALLTRADED, 价格: 17.6, 数量: 769.0
# symbol: 002921, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 19.85
# 2025-07-30 23:30:59.346923	逐日盯市盈亏计算完成
# 2025-07-30 23:30:59.346953	开始计算策略统计指标
# 2025-07-30 23:30:59.349626	策略统计指标计算完成
# 策略回测成功：002921，总净利润：32212.871700000047
# 2025-07-30 23:30:59.363527	历史数据加载完成，数据量：45
# symbol: 002652, 日期: 2025-02-05 00:00:00+08:00, 当前资金: 1388014.5122250002, 交易单位: 100, 目标仓位: 911.0, 目标价格: 15.23
# 订单状态更新: Status.ALLTRADED, 价格: 16.2, 数量: 911.0
# symbol: 002652, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 911.0, 目标仓位: 0, 目标价格: 15.28
# 订单状态更新: Status.ALLTRADED, 价格: 14.2, 数量: 911.0
# symbol: 002652, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 13.98
# 2025-07-30 23:30:59.365464	逐日盯市盈亏计算完成
# 2025-07-30 23:30:59.365503	开始计算策略统计指标
# 2025-07-30 23:30:59.368326	策略统计指标计算完成
# 策略回测成功：002652，总净利润：-53832.49314999997
# 2025-07-30 23:30:59.387220	历史数据加载完成，数据量：45
# symbol: 002910, 日期: 2025-02-05 00:00:00+08:00, 当前资金: 1388014.5122250002, 交易单位: 100, 目标仓位: 1809.0, 目标价格: 7.67
# 订单状态更新: Status.ALLTRADED, 价格: 8.6, 数量: 1809.0
# symbol: 002910, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 1809.0, 目标仓位: 0, 目标价格: 10.99
# 订单状态更新: Status.ALLTRADED, 价格: 10.0, 数量: 1809.0
# symbol: 002910, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.97
# 2025-07-30 23:30:59.389747	逐日盯市盈亏计算完成
# 2025-07-30 23:30:59.389782	开始计算策略统计指标
# 2025-07-30 23:30:59.412191	策略统计指标计算完成
# 策略回测成功：002910，总净利润：347232.05064000003
# 2025-07-30 23:30:59.429270	历史数据加载完成，数据量：45
# symbol: 002188, 日期: 2025-02-05 00:00:00+08:00, 当前资金: 1388014.5122250002, 交易单位: 100, 目标仓位: 1563.0, 目标价格: 8.88
# 订单状态更新: Status.ALLTRADED, 价格: 9.8, 数量: 1563.0
# symbol: 002188, 日期: 2025-03-03 00:00:00+08:00, 交易单位: 1563.0, 目标仓位: 0, 目标价格: 9.39
# 订单状态更新: Status.ALLTRADED, 价格: 8.4, 数量: 1563.0
# symbol: 002188, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 0.0, 目标仓位: 0, 目标价格: 8.96
# 2025-07-30 23:30:59.431278	逐日盯市盈亏计算完成
# 2025-07-30 23:30:59.431314	开始计算策略统计指标
# 2025-07-30 23:30:59.434306	策略统计指标计算完成
# 策略回测成功：002188，总净利润：1476.8630700000067
# 2025-2月总净利润：342218.8243799999
# 开始日期: 2025-03-01 00:00:00
# 候选标的：[{'symbol': '002856', 'name': '美芝股份', 'market_value': 1247584016.0}, {'symbol': '002207', 'name': '准油股份', 'market_value': 1291933003.6799998}, {'symbol': '000890', 'name': '法尔胜', 'market_value': 1329827578.56}, {'symbol': '002719', 'name': '麦趣尔', 'market_value': 1363511940.48}, {'symbol': '001211', 'name': '双枪科技', 'market_value': 1396800000.0}, {'symbol': '001336', 'name': '楚环科技', 'market_value': 1412966200.32}, {'symbol': '002921', 'name': '联诚精密', 'market_value': 1431889076.6399999}, {'symbol': '002652', 'name': '扬子新材', 'market_value': 1444020480.0}, {'symbol': '002910', 'name': '庄园牧场', 'market_value': 1472411260.32}, {'symbol': '002188', 'name': '中天服务', 'market_value': 1475238462.72}]
# 2025-07-30 23:31:08.798273	历史数据加载完成，数据量：27
# symbol: 002856, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1422236.3946630002, 交易单位: 100, 目标仓位: 1321.0, 目标价格: 10.76
# 订单状态更新: Status.ALLTRADED, 价格: 11.8, 数量: 1321.0
# symbol: 002856, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 1321.0, 目标仓位: 0, 目标价格: 10.36
# 订单状态更新: Status.ALLTRADED, 价格: 9.4, 数量: 1321.0
# 2025-07-30 23:31:08.804732	逐日盯市盈亏计算完成
# 2025-07-30 23:31:08.804809	开始计算策略统计指标
# 2025-07-30 23:31:08.810469	策略统计指标计算完成
# 策略回测成功：002856，总净利润：-107084.34189000004
# 2025-07-30 23:31:08.825519	历史数据加载完成，数据量：27
# symbol: 002207, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1422236.3946630002, 交易单位: 100, 目标仓位: 1230.0, 目标价格: 11.56
# 订单状态更新: Status.ALLTRADED, 价格: 12.6, 数量: 1230.0
# symbol: 002207, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 1230.0, 目标仓位: 0, 目标价格: 12.26
# 订单状态更新: Status.ALLTRADED, 价格: 11.2, 数量: 1230.0
# 2025-07-30 23:31:08.827283	逐日盯市盈亏计算完成
# 2025-07-30 23:31:08.827310	开始计算策略统计指标
# 2025-07-30 23:31:08.830986	策略统计指标计算完成
# 策略回测成功：002207，总净利润：4833.358800000133
# 2025-07-30 23:31:08.846367	历史数据加载完成，数据量：27
# symbol: 000890, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1422236.3946630002, 交易单位: 100, 目标仓位: 1800.0, 目标价格: 7.9
# 订单状态更新: Status.ALLTRADED, 价格: 8.8, 数量: 1800.0
# symbol: 000890, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 1800.0, 目标仓位: 0, 目标价格: 6.93
# 订单状态更新: Status.ALLTRADED, 价格: 6.0, 数量: 1800.0
# 2025-07-30 23:31:08.848354	逐日盯市盈亏计算完成
# 2025-07-30 23:31:08.848469	开始计算策略统计指标
# 2025-07-30 23:31:08.851597	策略统计指标计算完成
# 策略回测成功：000890，总净利润：-210679.32600000006
# 2025-07-30 23:31:08.866365	历史数据加载完成，数据量：27
# symbol: 002719, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1422236.3946630002, 交易单位: 100, 目标仓位: 1100.0, 目标价格: 12.92
# 订单状态更新: Status.ALLTRADED, 价格: 14.0, 数量: 1100.0
# symbol: 002719, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 1100.0, 目标仓位: 0, 目标价格: 11.81
# 订单状态更新: Status.ALLTRADED, 价格: 10.8, 数量: 1100.0
# 2025-07-30 23:31:08.868180	逐日盯市盈亏计算完成
# 2025-07-30 23:31:08.868211	开始计算策略统计指标
# 2025-07-30 23:31:08.870875	策略统计指标计算完成
# 策略回测成功：002719，总净利润：-146381.34499999994
# 2025-07-30 23:31:08.884730	历史数据加载完成，数据量：27
# symbol: 001211, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1422236.3946630002, 交易单位: 100, 目标仓位: 620.0, 目标价格: 22.92
# 订单状态更新: Status.ALLTRADED, 价格: 24.0, 数量: 620.0
# symbol: 001211, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 620.0, 目标仓位: 0, 目标价格: 22.67
# 订单状态更新: Status.ALLTRADED, 价格: 21.6, 数量: 620.0
# 2025-07-30 23:31:08.886487	逐日盯市盈亏计算完成
# 2025-07-30 23:31:08.886516	开始计算策略统计指标
# 2025-07-30 23:31:08.889046	策略统计指标计算完成
# 策略回测成功：001211，总净利润：-16205.559999999961
# 2025-07-30 23:31:08.902597	历史数据加载完成，数据量：27
# symbol: 001336, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1422236.3946630002, 交易单位: 100, 目标仓位: 740.0, 目标价格: 19.21
# 订单状态更新: Status.ALLTRADED, 价格: 20.2, 数量: 740.0
# symbol: 001336, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 740.0, 目标仓位: 0, 目标价格: 24.21
# 2025-07-30 23:31:08.904459	逐日盯市盈亏计算完成
# 2025-07-30 23:31:08.904488	开始计算策略统计指标
# 2025-07-30 23:31:08.906952	策略统计指标计算完成
# 策略回测成功：001336，总净利润：-143602.46859999985
# 2025-07-30 23:31:08.920616	历史数据加载完成，数据量：27
# symbol: 002921, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1422236.3946630002, 交易单位: 100, 目标仓位: 761.0, 目标价格: 18.68
# 订单状态更新: Status.ALLTRADED, 价格: 19.6, 数量: 761.0
# symbol: 002921, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 761.0, 目标仓位: 0, 目标价格: 19.85
# 订单状态更新: Status.ALLTRADED, 价格: 18.8, 数量: 761.0
# 2025-07-30 23:31:08.922291	逐日盯市盈亏计算完成
# 2025-07-30 23:31:08.922319	开始计算策略统计指标
# 2025-07-30 23:31:08.924800	策略统计指标计算完成
# 策略回测成功：002921，总净利润：42527.6935600001
# 2025-07-30 23:31:08.938824	历史数据加载完成，数据量：27
# symbol: 002652, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1422236.3946630002, 交易单位: 100, 目标仓位: 930.0, 目标价格: 15.28
# 订单状态更新: Status.ALLTRADED, 价格: 16.2, 数量: 930.0
# symbol: 002652, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 930.0, 目标仓位: 0, 目标价格: 13.98
# 订单状态更新: Status.ALLTRADED, 价格: 13.0, 数量: 930.0
# 2025-07-30 23:31:08.940559	逐日盯市盈亏计算完成
# 2025-07-30 23:31:08.940587	开始计算策略统计指标
# 2025-07-30 23:31:08.943083	策略统计指标计算完成
# 策略回测成功：002652，总净利润：-134931.77489999993
# 2025-07-30 23:31:08.956515	历史数据加载完成，数据量：27
# symbol: 002910, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1422236.3946630002, 交易单位: 100, 目标仓位: 1294.0, 目标价格: 10.99
# 订单状态更新: Status.ALLTRADED, 价格: 12.0, 数量: 1294.0
# symbol: 002910, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 1294.0, 目标仓位: 0, 目标价格: 8.97
# 订单状态更新: Status.ALLTRADED, 价格: 8.0, 数量: 1294.0
# 2025-07-30 23:31:08.958698	逐日盯市盈亏计算完成
# 2025-07-30 23:31:08.958754	开始计算策略统计指标
# 2025-07-30 23:31:08.961714	策略统计指标计算完成
# 策略回测成功：002910，总净利润：-164411.64153999992
# 2025-07-30 23:31:08.976331	历史数据加载完成，数据量：27
# symbol: 002188, 日期: 2025-03-03 00:00:00+08:00, 当前资金: 1422236.3946630002, 交易单位: 100, 目标仓位: 1514.0, 目标价格: 9.39
# 订单状态更新: Status.ALLTRADED, 价格: 10.4, 数量: 1514.0
# symbol: 002188, 日期: 2025-04-01 00:00:00+08:00, 交易单位: 1514.0, 目标仓位: 0, 目标价格: 8.96
# 订单状态更新: Status.ALLTRADED, 价格: 8.0, 数量: 1514.0
# 2025-07-30 23:31:08.978048	逐日盯市盈亏计算完成
# 2025-07-30 23:31:08.978079	开始计算策略统计指标
# 2025-07-30 23:31:08.980913	策略统计指标计算完成
# 策略回测成功：002188，总净利润：-131801.16402000008
# 2025-3月总净利润：-1007736.5695899995
# 2025-07-30 23:31:09.001197	开始计算策略统计指标
# 2025-07-30 23:31:09.004705	策略统计指标计算完成
# 总净利润：3214627.3770400006

# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.path.curdir, ".."))
sys.path.append(parent_dir)
from chart_tools import app
import dash
from dash import html, dcc, callback, Input, Output, State, ALL, MATCH
import plotly.graph_objects as go
from akshare.akshare.stock.stock_board_concept_em import stock_board_concept_hist_em
from akshare.akshare.stock.stock_zh_a_sina import stock_zh_a_daily
from akshare.akshare.index.index_stock_zh import stock_zh_index_daily_em
from plotly.subplots import make_subplots


app.run_server(debug=True, port=8883)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8883/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# hover_data None
# hover_data None
# hover_data None
# hover_data None
# start date: 2024-04-01 00:00:00, end date: 2025-03-31 00:00:00, symbol: 002193.SZSE
# hover_data None
# hover_data None
# hover_data None
# hover_data None
# hover_data None
# start date: 2024-04-01 00:00:00, end date: 2025-03-31 00:00:00, symbol: 002193.SZSE

# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.path.curdir, ".."))
sys.path.append(parent_dir)
# from chart_tools import app
import dash
from dash import html, dcc, callback, Input, Output, State, ALL, MATCH
import plotly.graph_objects as go
from akshare.akshare.stock.stock_board_concept_em import stock_board_concept_hist_em
from akshare.akshare.stock.stock_zh_a_sina import stock_zh_a_daily
from akshare.akshare.index.index_stock_zh import stock_zh_index_daily_em
from plotly.subplots import make_subplots



concept_hist_em = stock_board_concept_hist_em('微盘股', period='daily', start_date='20240401', end_date='20250331', adjust='hfq')
hs300_index_daily = stock_zh_index_daily_em('sz399300', start_date='20240401', end_date='20250331')


integrated_df["balance"] = integrated_df["net_pnl"].cumsum()
fig = go.Figure()
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(
        x = integrated_df.index,
        y = integrated_df['balance'],
    ),
    secondary_y=False
)

# fig.add_trace(go.Scatter(
#     x=concept_hist_em['日期'],
#     y=concept_hist_em['收盘']
#     ),
#     secondary_y=True
# )

fig.add_trace(go.Scatter(
    x=hs300_index_daily['date'],
    y=hs300_index_daily['close']
    ),
    secondary_y=True
)

app = dash.Dash(__name__)
app.layout = html.Div([
    # html.H1("candle图", style={'textAlign': 'center'}),
    
    # 控制面板
    html.Div([
        dcc.Graph(
            id='balance-graph',
            figure=fig
        )
    ], style={'width': '200%', 'height': '100%','margin': '20px', 'display': 'inline-block'})
])
app.run_server(debug=True, port=8883)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8883/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from vnpy_ctabacktester.ui.widget import CandleChartDialog
from vnpy.trader.object import TradeData, BarData
from vnpy_ctastrategy.backtesting import (
    BacktestingEngine,
    OptimizationSetting,
    BacktestingMode
)
import sys
from vnpy.trader.ui import QtCore, QtWidgets, QtGui, create_qapp
def show_candle_chart(engine_ins: BacktestingEngine) -> None:
    """"""
    try:
        app = QtWidgets.QApplication.instance()
        if app is None:
            app = create_qapp('show_candle_chart')
        candle_dialog: CandleChartDialog = CandleChartDialog()
        if not candle_dialog.is_updated():
            history: list = engine_ins.history_data
            candle_dialog.update_history(history)

            trades: list[TradeData] = engine_ins.get_all_trades()
            candle_dialog.update_trades(trades)

        candle_dialog.exec_()
    except Exception as e:
        print(f"显示K线图表失败: {e}")
        return
    
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from pandas import DataFrame, Series


def show_chart(df: DataFrame, candle_df: DataFrame) -> go.Figure:
    """显示回测结果图表"""

    fig = make_subplots(
        rows=6,
        cols=1,
        shared_xaxes=True,
        vertical_spacing=0.06
    )

    balance_line = go.Scatter(
        x=df.index,
        y=df["balance"],
        mode="lines",
        name="Balance"
    )

    drawdown_scatter = go.Scatter(
        x=df.index,
        y=df["drawdown"],
        fillcolor="red",
        fill='tozeroy',
        mode="lines",
        name="Drawdown"
    )
    pnl_bar = go.Bar(y=df["net_pnl"], x=df.index, name="Daily Pnl")

    fig.add_trace(balance_line, row=1, col=1)
    fig.add_trace(drawdown_scatter, row=2, col=1)
    fig.add_trace(pnl_bar, row=3, col=1)
    fig.add_trace(go.Candlestick(
        x=candle_df.index,
        open=candle_df['open_price'],
        high=candle_df['high_price'],
        low=candle_df['low_price'],
        close=candle_df['close_price'],
        name="OHLC"
    ), row=4, col=1)
    
    colors = ['green' if close < open else 'red' 
              for close, open in zip(candle_df['close_price'], candle_df['open_price'])]
    
    fig.add_trace(
        go.Bar(
            x=candle_df.index,
            y=candle_df['volume'],
            name="成交量",
            marker_color=colors,
            opacity=0.7
        ),
        row=5, col=1
    )

    fig.update_xaxes(title_text="日期", row=5, col=1)
    fig.update_yaxes(title_text="balance", row=1, col=1)
    fig.update_yaxes(title_text="drawdown", row=2, col=1)
    fig.update_yaxes(title_text="Daily Pnl", row=3, col=1)
    fig.update_yaxes(title_text="价格", row=4, col=1)
    fig.update_yaxes(title_text="成交量", row=5, col=1)

    fig.update_layout(height=800, 
                    width=800, 
                    xaxis4_rangeslider_visible = False,
                    xaxis5_rangeslider=dict(
                        visible=True,
                        thickness=0.01,  # 减小滑块厚度
                        bgcolor="lightgray"
                    )
)
    return fig

# %%
# len(record_engines)
# record_engines[0].history_data
# candle_dialog: CandleChartDialog = CandleChartDialog()
show_candle_chart(record_engines[0])

# %%
from collections import defaultdict

df = list(record_df_dicts[0].values())[0]

results = defaultdict(list)
test = list(record_candle_dicts[0].values())[0]
for daily_bar in test:
    for key, value in daily_bar.__dict__.items():
        results[key].append(value)
    # results['date'] = daily_bar.datetime.strftime("%Y-%m-%d %H:%M:%S")
candle_df = DataFrame.from_dict(results).set_index('datetime')
# print(type(test))
show_chart(df, candle_df)

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("atr_length", 25, 27, 1)
setting.add_parameter("atr_ma_length", 10, 30, 10)

engine.run_ga_optimization(setting)

# %%
engine.run_bf_optimization(setting)

# %%
# Out:
#            date     open    close     high      low     volume        amount
# 0    2024-04-01  3551.58  3595.65  3600.92  3551.58  162776561  2.516373e+11
# 1    2024-04-02  3593.22  3580.68  3596.19  3568.75  141272972  2.202075e+11
# 2    2024-04-03  3578.68  3567.80  3582.43  3558.87  135592331  2.142229e+11
# 3    2024-04-08  3553.56  3536.41  3567.82  3535.77  155304283  2.432493e+11
# 4    2024-04-09  3533.38  3533.49  3543.71  3518.86  129670942  1.958935e+11
# ..          ...      ...      ...      ...      ...        ...           ...
# 236  2025-03-25  3937.90  3932.30  3946.36  3921.53  140475399  2.392463e+11
# 237  2025-03-26  3930.21  3919.36  3942.03  3916.86  131164187  2.209432e+11
# 238  2025-03-27  3911.38  3932.41  3952.99  3903.65  126793738  2.321736e+11
# 239  2025-03-28  3930.78  3915.17  3934.23  3907.38  126356214  2.133792e+11
# 240  2025-03-31  3905.98  3887.31  3928.45  3872.40  166798523  2.684803e+11
#
# [241 rows x 7 columns]

# %%
# Out:
#              日期       开盘       收盘       最高       最低   涨跌幅    涨跌额       成交量  \
# 0    2024-04-01  1427.83  1460.56  1460.56  1427.83  2.62  37.27  25506320
# 1    2024-04-02  1462.32  1473.96  1479.78  1461.86  0.92  13.40  27917562
# 2    2024-04-03  1472.36  1462.38  1472.70  1440.89 -0.79 -11.58  28306878
# 3    2024-04-08  1456.58  1396.10  1456.58  1395.29 -4.53 -66.28  29838998
# 4    2024-04-09  1396.25  1425.95  1425.95  1396.25  2.14  29.85  21121380
# ..          ...      ...      ...      ...      ...   ...    ...       ...
# 236  2025-03-25  2138.46  2136.30  2150.38  2101.05 -0.22  -4.65  28397854
# 237  2025-03-26  2130.01  2188.62  2199.85  2126.33  2.45  52.32  28481226
# 238  2025-03-27  2186.46  2171.59  2188.37  2137.39 -0.78 -17.03  26832296
# 239  2025-03-28  2167.81  2123.31  2171.29  2123.28 -2.22 -48.28  22532262
# 240  2025-03-31  2108.88  2097.44  2109.31  2063.44 -1.22 -25.87  23461684
#
#               成交额    振幅   换手率
# 0    1.976344e+10  2.30  3.27
# 1    2.158200e+10  1.23  3.58
# 2    2.127419e+10  2.16  3.63
# 3    2.142211e+10  4.19  3.83
# 4    1.550453e+10  2.13  2.71
# ..            ...   ...   ...
# 236  2.230271e+10  2.30  3.64
# 237  2.210952e+10  3.44  3.65
# 238  2.106199e+10  2.33  3.44
# 239  1.795066e+10  2.21  2.89
# 240  1.779735e+10  2.16  3.01
#
# [241 rows x 11 columns]
